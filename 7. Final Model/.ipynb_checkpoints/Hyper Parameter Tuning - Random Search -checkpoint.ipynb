# %%
# Python Standard Libraries for importing data from binary file
import os.path #for accessing the file path
import struct  #for unpacking the binary data

import time    #for calculating time
import math    #for using floor in creating minibatches


#core packages
import numpy as np
import matplotlib.pyplot as plt

#custom module
from dataPrep import load_dataset, load_sample_dataset
from dataPrep import prep_dataset, rand_mini_batches

from finalModelUtils import *
from ffnn import *

np.random.seed(1)
# %matplotlib inline

# %%
#loading complete dataset
train_x_orig, train_y_orig, dev_x_orig,dev_y_orig,test_x_orig,test_y_orig = load_dataset()

# %%
#loading Sample dataset
sample_size = 25
train_x_sample, train_y_sample, dev_x_sample, dev_y_sample, test_x_sample, test_y_sample = load_sample_dataset(sample_size)

print("Sample Size : %d%%\n"%(sample_size))
print("Data\t\t\t","Complete Dataset\t","Sample Dataset\t")
print("================================================================")
print("Training Set Images:\t"+ str(train_x_orig.shape)+"\t\t"+ str(train_x_sample.shape))
print("Training Set Labels:\t"+ str(train_y_orig.shape)+"\t\t"+ str(train_y_sample.shape))
print("Training Set Images:\t"+ str(dev_x_orig.shape)+"\t\t"+ str(dev_x_sample.shape))
print("Training Set Labels:\t"+ str(dev_y_orig.shape)+"\t\t"+ str(dev_y_sample.shape))
print("Test Set Images:\t"+str(test_x_orig.shape)+"\t\t"+ str(test_x_sample.shape))
print("Test Set Labels:\t"+str(test_y_orig.shape)+"\t\t"+ str(test_y_sample.shape))
print("================================================================")
# Out:
# Sample Size : 25%
#
# Data			 Complete Dataset	 Sample Dataset
# ================================================================
# Training Set Images:	(60000, 28, 28)		(15000, 28, 28)
# Training Set Labels:	(60000, 1)		(15000, 1)
# Training Set Images:	(5000, 28, 28)		(1250, 28, 28)
# Training Set Labels:	(5000, 1)		(1250, 1)
# Test Set Images:	(5000, 28, 28)		(1250, 28, 28)
# Test Set Labels:	(5000, 1)		(1250, 1)
# ================================================================

# %%
# Preparing the Dataset (Flattening and Normalizing)
train_x_norm,train_y_encoded, dev_x_norm,dev_y_encoded, test_x_norm, test_y_encoded = prep_dataset(train_x_sample, train_y_sample, dev_x_sample, dev_y_sample, test_x_sample, test_y_sample)
print("Data\t\t\t","Before Processing\t","After Processing")
print("=================================================================")
print("Training Set Images:\t" + str(train_x_sample.shape)+"\t\t"+ str(train_x_norm.shape))
print("Training Set Labels:\t" + str(train_y_sample.shape)+"\t\t"+ str(train_y_encoded.shape))
print("Dev Set Images:\t\t" + str(dev_x_sample.shape)+"\t\t"+ str(dev_x_norm.shape))
print("Dev Set Labels:\t\t" + str(dev_y_sample.shape)+"\t\t"+ str(dev_y_encoded.shape))
print("Test Set Images:\t" + str(test_x_sample.shape)+"\t\t"+ str(test_x_norm.shape))
print("Test Set Labels:\t" + str(test_y_sample.shape)+"\t\t"+ str(test_y_encoded.shape))
print("=================================================================")
# Out:
# Data			 Before Processing	 After Processing
# =================================================================
# Training Set Images:	(15000, 28, 28)		(784, 15000)
# Training Set Labels:	(15000, 1)		(10, 15000)
# Dev Set Images:		(1250, 28, 28)		(784, 1250)
# Dev Set Labels:		(1250, 1)		(10, 1250)
# Test Set Images:	(1250, 28, 28)		(784, 1250)
# Test Set Labels:	(1250, 1)		(10, 1250)
# =================================================================

# %% [markdown]
# ## Model Implementation

# %%
layers_dim = init_layers(train_x_norm, train_y_encoded, hidden_layers = [800,300])

# %%
hyperParams = init_hyperParams(alpha = 0.0001, num_epoch = 5, mini_batch_size = 512,lambd = 0.7,keep_probs = [0.9,0.8,])

# %%
parameters = train(train_x_norm, train_y_encoded,dev_x_norm, dev_y_encoded,layers_dim, hyperParams, initialization = "he", optimizer = 'adam',regularizer = 'l2')

# %% [markdown]
# ## Random Search 2D

# %% [markdown]
# ### Random Sampling

# %%
sam = []
for i in range(100):
    r = np.random.uniform(-5, -1)
    p = 10 ** r
#     print(r,p)
    sam.append(p)


plt.hist(sam,bins = 10)
    
    
plt.xscale('log')
plt.grid()

# %%
def sample_hyperParams(hParam_type, rng, sample_size):

    sample = []
    
    lower_range = rng[0]
    higher_range = rng[1]
    
    
    for i in range(sample_size):
        if hParam_type == "learning_rate":
            r = np.random.uniform(lower_range,higher_range)
            p = 10 ** r
            sample.append(p)
        elif hParam_type == "minibatch_size":
            s = np.random.randint(low = lower_range, high = higher_range)
            sample.append(s)
        else:
            raise ValueError("Sampling of only learning rate and minibatch size is possible for now")
            
    assert(len(sample) == sample_size)
    return sample

# %%
leaning_rate_ = sample_hyperParams(hParam_type ="learning_rate",rng = [-5,-1],sample_size = 300)
minibatch_size_ = sample_hyperParams(hParam_type ="minibatch_size",rng = [50,2200],sample_size = 300)


fig, ax = plt.subplots(nrows = 2, ncols = 2, figsize=(20,10))
# ax.set_yticklabels([0,0.00001, 0.0001, 0.001, 0.01, 0.1],fontsize=16)
ax[0,0].set_ylim(top = 10e-2, bottom = 10e-6)
ax[0,0].scatter(minibatch_size_,leaning_rate_)
ax[0,0].set_yscale('log')
ax[0,0].grid()

num_mini_batch = ax[1,0].hist(minibatch_size_, bins = 20)

num_alpha = ax[1,1].hist(leaning_rate_, bins = 100)
ax[1,1].set_xscale('log') #changing the scale to log scale to plot learning rate which is in log scale
plt.show()

# print(leaning_rate_samples[0:10],minibatch_size_samples[0:10])

# %%
sc = np.random.uniform(0,1,100)
# print(sc)
thres = 0.90

lr = []
for i in range(100):
    r = np.random.uniform(-5, -1)
    p = 10 ** r
    lr.append(p)
    
mbz = np.random.randint(50,2200,100)
# print(lr)
# print(mbz)

best_lr = []
best_mbz = []
best_sc = []

for ind, val in enumerate(sc):
    if val > thres:
        best_lr.append(lr[ind])
        best_mbz.append(mbz[ind])
        best_sc.append(val)


# print(best_lr)
# print(best_mbz)
print(best_sc, end = "\n\n")

print(np.max(best_sc), np.argmax(best_sc))

if len(best_sc) !=0:
    
    #generating the log range
    lg_min_lr = np.log10(min(best_lr))
    lg_max_lr = np.log10(max(best_lr))
    
    print(lg_min_lr,lg_max_lr)
    #generating the minimum change
    min_change = 2 * (10 ** int(lg_min_lr-2))
    max_change = 2 * (10 ** int(lg_max_lr-2))
    print(min(best_lr),max(best_lr))
    print(min_change,max_change, end = "\n\n")
    
#   slightly expanding the range
    print(min(best_lr) - min_change,max(best_lr)+max_change)
    print(np.log10(min(best_lr) - min_change),np.log10(max(best_lr)+max_change))
    
    
    
    print(min(best_mbz), max(best_mbz))
    print(min(best_mbz)-20, max(best_mbz)+20)
    
    

else:
    print("No pair hyper parameters could give the accuracy beyond the Threshold")

# %%
def calculate_new_range(score, threshold, samples, summary = True):
    learning_rate = samples["learning rate"]
    minibatch_size = samples["minibatch size"]
    
    good_lrs = []
    good_mbs = []
    good_scs = []
#     best_comb = []
    
    #getting the score above the threshold and along with their corresponding hyper parameters
    for ind, val in enumerate(score):
        if val > threshold:
            good_lrs.append(learning_rate[ind])
            good_mbs.append(minibatch_size[ind])
            good_scs.append(val)
            
    if len(good_scs) !=0:
    
        #generating the log range for learning rate
        lg_min_lr = np.log10(min(good_lrs))
        lg_max_lr = np.log10(max(good_lrs))

        #generating the minimum change for learning rate
        min_lr_change = 2 * (10 ** int(lg_min_lr-2))
        max_lr_change = 2 * (10 ** int(lg_max_lr-2))
        
        #calculating the new search range in log10 form after expanding the learning rate space
        exp_lr_min = min(good_lrs) - min_lr_change
        exp_lr_max = max(good_lrs) + max_lr_change
        lr_rng_small = [np.log10(exp_lr_min), np.log10(exp_lr_max)]


        #calculating the new search range for minibatch size by expanding the search space
        mbs_rng_small = [min(good_mbs)-20, max(good_mbs) + 20]
        
        #best hyper parameter combinations
        best_comb = [np.max(good_scs),good_lrs[np.argmax(good_scs)],good_mbs[np.argmax(good_scs)]]

    else:
        print("No pair hyper parameters could give the accuracy beyond the Threshold")
    
    if summary == True:
        print("+================+===============+================+")
        print("| Validation Acc | Learning Rate | Minibatch Size |")
        print("+================+===============+================+")

        for ind,sc in enumerate(good_scs):
            print("| %.5f\t | %.5f\t | %d\t\t  |"%(sc, good_lrs[ind], good_mbs[ind]))

        print("+================+===============+================+")



        print("New Search Space for Learning Rate: [%.6f,%.6f]"%(exp_lr_min, exp_lr_max))
        print("New Search Space for Minibatch Size: [%d,%d]"%(mbs_rng_small[0], mbs_rng_small[1]))
        print("Best Score: %.6f "%(best_comb[0]))
        print("Best Hyper Params:\n Learning Rate: %.6f\n Minibatch Size: %d"%(best_comb[1], best_comb[2]))
  
        
    
    return lr_rng_small, mbs_rng_small, best_comb

# %%
sc = np.random.uniform(0,1,100)
# print(sc)
thres = 0.90

lr = []
for i in range(100):
    r = np.random.uniform(-5, -1)
    p = 10 ** r
    lr.append(p)
    
mbz = np.random.randint(50,2200,100)

samples = {"learning rate": lr,
               "minibatch size" : mbz}
score_threshold = 0.90


lr_rng, mbs_rng, best = calculate_new_range(sc,score_threshold,samples, summary = True)

# %%
#Coarse search with 2 epoch, fine search with 5 epoch and detailed search with 10 epoch

def random_search_2D(param1, param2, search_type ="coarse", evaluate_metric = "test_acc", sample_size = 100, summary = True):
    
    
    hParam_type1 = param1["hParam type"]
    hParam_range1 = param1["hParam range"]
    
    hParam_type2 = param2["hParam type"]
    hParam_range2 = param2["hParam range"]
    
    if search_type == "coarse":
        epoch_size = 2
        score_threshold = 0.90
    elif search_type == "fine":
        epoch_size = 5
        score_threshold = 0.95
    elif search_type == "detail":
        epoch_size = 10
        score_threshold = 0.97
    else:
        raise ValueError("Search Type not identified. Must be 'coarse', 'fine', or 'detail'")
    
    ##generating Samples
    leaning_rate_samples = sample_hyperParams(hParam_type = hParam_type1, rng = hParam_range1, sample_size = sample_size)
    minibatch_size_samples = sample_hyperParams(hParam_type = hParam_type2,rng = hParam_range2, sample_size = sample_size)
    
    samples = {"learning rate": leaning_rate_samples,
               "minibatch size" : minibatch_size_samples}
    

    score = []
    
    toc = time.time()
        
    for i in range(sample_size):
                
        print("\nSample: %d/%d -- Learning Rate: %.6f | Minibatch Size: %d"%(i+1,sample_size,leaning_rate_samples[i],minibatch_size_samples[i]))
        print("==========================================================================================================")
        
        hyperParams = init_hyperParams(alpha = leaning_rate_samples[i], num_epoch = epoch_size, mini_batch_size = minibatch_size_samples[i])
        
        parameters = train(train_x_norm, train_y_encoded, dev_x_norm, dev_y_encoded,layers_dim, hyperParams, initialization = "he", optimizer = 'adam', visualize = False) 
        
        if evaluate_metric == "test_acc": 
            _,test_acc,_ = predict(test_x_norm, test_y_encoded,parameters)
            score.append(test_acc)

        elif evaluate_metric == "val_acc":
            prediction_dev,dev_acc, _ = predict(dev_x_norm, dev_y_encoded,parameters)
            score.append(dev_acc)

        else:
            raise ValueError("Metric must be 'val_acc' or 'test_acc'")
        
    print("==========================================================================================================")
    
    tic = time.time() # for calculating entire search time
    hrs, mins, secs , ms = convert_time((tic - toc)*1000)
    
    print("\n\n*************************** Total Search Time = %dhr %dmins %dsecs %.2fms ***************************\n\n"%(hrs, mins, secs, ms))
    
    assert(len(score) == sample_size)
    
    if summary == True:
        print(search_type.capitalize()+" Search Summary for Hyper Parameters with high Accuracy: \n")
    lr_rng_small, mbs_rng_small, best_comb = calculate_new_range(score, score_threshold, samples, summary = summary)
    
    return lr_rng_small, mbs_rng_small, best_comb

# %%
#Coarse Random Search
lr_rng_coarse = [-4,-1]
mbs_rng_coarse = [50,2200]

param1_coarse = {"hParam type": "learning_rate" ,
          "hParam range": lr_rng_coarse }
    
param2_coarse = {"hParam type": "minibatch_size",
          "hParam range": mbs_rng_coarse } 
    
lr_rng_fine, mbs_rng_fine, best_comb = random_search_2D(param1 = param1_coarse, param2 = param2_coarse , search_type ="coarse", evaluate_metric = "test_acc", sample_size = 60, summary = True)
# Out:
# Sample: 1/60 -- Learning Rate: 0.037885 | Minibatch Size: 117
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 47.99s | loss: 0.3993 | acc: 0.8872 | Val loss: 0.3981 | Val acc: 0.8848
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 50.37s | loss: 0.2614 | acc: 0.9295 | Val loss: 0.2749 | Val acc: 0.9248
#
# *************************** Total Training Time = 0hr 1mins 38secs 439.33ms ***************************
#
# Sample: 2/60 -- Learning Rate: 0.004453 | Minibatch Size: 1000
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 7.10s | loss: 0.2905 | acc: 0.9169 | Val loss: 0.2768 | Val acc: 0.9248
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 7.07s | loss: 0.1650 | acc: 0.9523 | Val loss: 0.1765 | Val acc: 0.9512
#
# *************************** Total Training Time = 0hr 0mins 14secs 225.18ms ***************************
#
# Sample: 3/60 -- Learning Rate: 0.000237 | Minibatch Size: 1211
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 6.67s | loss: 1.1516 | acc: 0.7939 | Val loss: 1.1317 | Val acc: 0.7992
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 6.94s | loss: 0.5905 | acc: 0.8684 | Val loss: 0.5535 | Val acc: 0.8856
#
# *************************** Total Training Time = 0hr 0mins 13secs 671.37ms ***************************
#
# Sample: 4/60 -- Learning Rate: 0.041277 | Minibatch Size: 657
# ==========================================================================================================
#
# Epoch: 1/2
# /home/befrenz/Sameer Kattel/Education/Course/CSIT/7th Semester/Project Work/HandWritten-Digit-Recognition-using-Deep-Learning/7. Final Model/ffnn.py:162: RuntimeWarning: divide by zero encountered in log
#   cost = -(1./m) * np.sum(np.sum(np.multiply(Y,np.log(AL)), axis = 0,keepdims=True))
# /home/befrenz/Sameer Kattel/Education/Course/CSIT/7th Semester/Project Work/HandWritten-Digit-Recognition-using-Deep-Learning/7. Final Model/ffnn.py:162: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1./m) * np.sum(np.sum(np.multiply(Y,np.log(AL)), axis = 0,keepdims=True))
# 15000/15000 [==========> 100%] - 10.35s | loss: 0.6356 | acc: 0.7891 | Val loss: 0.6027 | Val acc: 0.7960
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 9.85s | loss: 0.3802 | acc: 0.8807 | Val loss: 0.3922 | Val acc: 0.8744
#
# *************************** Total Training Time = 0hr 0mins 20secs 259.72ms ***************************
#
# Sample: 5/60 -- Learning Rate: 0.000100 | Minibatch Size: 460
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 16.65s | loss: 1.1205 | acc: 0.8070 | Val loss: 1.0994 | Val acc: 0.8184
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 15.39s | loss: 0.5755 | acc: 0.8760 | Val loss: 0.5406 | Val acc: 0.8896
#
# *************************** Total Training Time = 0hr 0mins 32secs 103.71ms ***************************
#
# Sample: 6/60 -- Learning Rate: 0.000102 | Minibatch Size: 2175
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 3.99s | loss: 1.9900 | acc: 0.3787 | Val loss: 2.0103 | Val acc: 0.3720
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 3.95s | loss: 1.6772 | acc: 0.6369 | Val loss: 1.6849 | Val acc: 0.6432
#
# *************************** Total Training Time = 0hr 0mins 7secs 996.15ms ***************************
#
# Sample: 7/60 -- Learning Rate: 0.032530 | Minibatch Size: 1667
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 4.37s | loss: 0.9515 | acc: 0.7016 | Val loss: 0.8909 | Val acc: 0.7144
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 4.29s | loss: 0.3870 | acc: 0.8914 | Val loss: 0.3307 | Val acc: 0.9064
#
# *************************** Total Training Time = 0hr 0mins 8secs 706.37ms ***************************
#
# Sample: 8/60 -- Learning Rate: 0.002051 | Minibatch Size: 153
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 41.98s | loss: 0.1486 | acc: 0.9549 | Val loss: 0.1858 | Val acc: 0.9488
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 43.09s | loss: 0.0819 | acc: 0.9737 | Val loss: 0.1359 | Val acc: 0.9648
#
# *************************** Total Training Time = 0hr 1mins 25secs 147.39ms ***************************
#
# Sample: 9/60 -- Learning Rate: 0.052590 | Minibatch Size: 826
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 8.19s | loss: 0.8369 | acc: 0.7398 | Val loss: 0.8191 | Val acc: 0.7656
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 8.16s | loss: 0.5075 | acc: 0.8515 | Val loss: 0.5658 | Val acc: 0.8488
#
# *************************** Total Training Time = 0hr 0mins 16secs 410.25ms ***************************
#
# Sample: 10/60 -- Learning Rate: 0.013420 | Minibatch Size: 2061
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 4.03s | loss: 1.1069 | acc: 0.6600 | Val loss: 1.0398 | Val acc: 0.6808
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 3.98s | loss: 0.4043 | acc: 0.8909 | Val loss: 0.3840 | Val acc: 0.9000
#
# *************************** Total Training Time = 0hr 0mins 8secs 64.14ms ***************************
#
# Sample: 11/60 -- Learning Rate: 0.000160 | Minibatch Size: 953
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 7.99s | loss: 1.3039 | acc: 0.7685 | Val loss: 1.2925 | Val acc: 0.7704
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 7.81s | loss: 0.7132 | acc: 0.8537 | Val loss: 0.6785 | Val acc: 0.8680
#
# *************************** Total Training Time = 0hr 0mins 15secs 866.11ms ***************************
#
# Sample: 12/60 -- Learning Rate: 0.001251 | Minibatch Size: 2074
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 4.37s | loss: 0.4619 | acc: 0.8719 | Val loss: 0.4240 | Val acc: 0.8824
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 4.30s | loss: 0.3211 | acc: 0.9069 | Val loss: 0.3131 | Val acc: 0.9112
#
# *************************** Total Training Time = 0hr 0mins 8secs 725.98ms ***************************
#
# Sample: 13/60 -- Learning Rate: 0.004250 | Minibatch Size: 150
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 42.31s | loss: 0.1491 | acc: 0.9530 | Val loss: 0.1874 | Val acc: 0.9432
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 42.11s | loss: 0.0683 | acc: 0.9794 | Val loss: 0.1144 | Val acc: 0.9704
#
# *************************** Total Training Time = 0hr 1mins 24secs 499.14ms ***************************
#
# Sample: 14/60 -- Learning Rate: 0.005987 | Minibatch Size: 780
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 9.05s | loss: 0.2544 | acc: 0.9275 | Val loss: 0.2471 | Val acc: 0.9304
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 8.98s | loss: 0.1462 | acc: 0.9571 | Val loss: 0.1573 | Val acc: 0.9560
#
# *************************** Total Training Time = 0hr 0mins 18secs 86.30ms ***************************
#
# Sample: 15/60 -- Learning Rate: 0.001350 | Minibatch Size: 1279
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 6.05s | loss: 0.3584 | acc: 0.8948 | Val loss: 0.3274 | Val acc: 0.9072
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 5.98s | loss: 0.2372 | acc: 0.9323 | Val loss: 0.2483 | Val acc: 0.9320
#
# *************************** Total Training Time = 0hr 0mins 12secs 78.15ms ***************************
#
# Sample: 16/60 -- Learning Rate: 0.087386 | Minibatch Size: 1713
# ==========================================================================================================
#
# Epoch: 1/2
# /home/befrenz/Sameer Kattel/Education/Course/CSIT/7th Semester/Project Work/HandWritten-Digit-Recognition-using-Deep-Learning/7. Final Model/finalModelUtils.py:64: RuntimeWarning: invalid value encountered in true_divide
#   A = np.divide(t,np.sum(t,axis = 0))
# 3426/15000 [==>........ 23%] - 0.96s | loss: nan | acc: 0.0977 | Val loss: nan | Val acc: 0.0840
# /home/befrenz/Sameer Kattel/Education/Course/CSIT/7th Semester/Project Work/HandWritten-Digit-Recognition-using-Deep-Learning/7. Final Model/finalModelUtils.py:45: RuntimeWarning: invalid value encountered in less
#   dZ[Z < 0] = 0
# 15000/15000 [==========> 100%] - 4.04s | loss: nan | acc: 0.0977 | Val loss: nan | Val acc: 0.0840
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 3.97s | loss: nan | acc: 0.0977 | Val loss: nan | Val acc: 0.0840
#
# *************************** Total Training Time = 0hr 0mins 8secs 64.47ms ***************************
#
# Sample: 17/60 -- Learning Rate: 0.000126 | Minibatch Size: 1174
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 6.53s | loss: 1.6090 | acc: 0.6685 | Val loss: 1.6130 | Val acc: 0.6736
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 6.47s | loss: 1.0652 | acc: 0.8128 | Val loss: 1.0429 | Val acc: 0.8216
#
# *************************** Total Training Time = 0hr 0mins 13secs 47.01ms ***************************
#
# Sample: 18/60 -- Learning Rate: 0.089180 | Minibatch Size: 370
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 15.12s | loss: nan | acc: 0.0977 | Val loss: nan | Val acc: 0.0840
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 15.29s | loss: nan | acc: 0.0977 | Val loss: nan | Val acc: 0.0840
#
# *************************** Total Training Time = 0hr 0mins 30secs 472.26ms ***************************
#
# Sample: 19/60 -- Learning Rate: 0.005315 | Minibatch Size: 790
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 8.64s | loss: 0.2738 | acc: 0.9207 | Val loss: 0.2619 | Val acc: 0.9264
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 8.59s | loss: 0.1383 | acc: 0.9586 | Val loss: 0.1579 | Val acc: 0.9560
#
# *************************** Total Training Time = 0hr 0mins 17secs 286.46ms ***************************
#
# Sample: 20/60 -- Learning Rate: 0.076804 | Minibatch Size: 72
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 80.27s | loss: 1.4294 | acc: 0.3826 | Val loss: 1.3936 | Val acc: 0.4000
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 79.54s | loss: 1.3900 | acc: 0.4217 | Val loss: 1.3590 | Val acc: 0.4528
#
# *************************** Total Training Time = 0hr 2mins 39secs 925.72ms ***************************
#
# Sample: 21/60 -- Learning Rate: 0.000176 | Minibatch Size: 835
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 8.70s | loss: 1.1327 | acc: 0.8021 | Val loss: 1.1117 | Val acc: 0.8096
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 8.67s | loss: 0.5756 | acc: 0.8719 | Val loss: 0.5381 | Val acc: 0.8920
#
# *************************** Total Training Time = 0hr 0mins 17secs 429.36ms ***************************
#
# Sample: 22/60 -- Learning Rate: 0.000669 | Minibatch Size: 579
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 11.96s | loss: 0.3123 | acc: 0.9101 | Val loss: 0.2935 | Val acc: 0.9216
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 11.88s | loss: 0.2028 | acc: 0.9455 | Val loss: 0.2092 | Val acc: 0.9432
#
# *************************** Total Training Time = 0hr 0mins 23secs 897.07ms ***************************
#
# Sample: 23/60 -- Learning Rate: 0.008277 | Minibatch Size: 492
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 13.21s | loss: 0.2075 | acc: 0.9392 | Val loss: 0.2089 | Val acc: 0.9384
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 13.13s | loss: 0.1214 | acc: 0.9637 | Val loss: 0.1551 | Val acc: 0.9592
#
# *************************** Total Training Time = 0hr 0mins 26secs 404.35ms ***************************
#
# Sample: 24/60 -- Learning Rate: 0.001674 | Minibatch Size: 1989
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 4.38s | loss: 0.4223 | acc: 0.8779 | Val loss: 0.3835 | Val acc: 0.8832
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 4.31s | loss: 0.2915 | acc: 0.9199 | Val loss: 0.2925 | Val acc: 0.9208
#
# *************************** Total Training Time = 0hr 0mins 8secs 747.54ms ***************************
#
# Sample: 25/60 -- Learning Rate: 0.001112 | Minibatch Size: 187
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 34.65s | loss: 0.1708 | acc: 0.9526 | Val loss: 0.1923 | Val acc: 0.9448
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 35.16s | loss: 0.0952 | acc: 0.9733 | Val loss: 0.1397 | Val acc: 0.9624
#
# *************************** Total Training Time = 0hr 1mins 9secs 893.25ms ***************************
#
# Sample: 26/60 -- Learning Rate: 0.000109 | Minibatch Size: 1725
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 4.84s | loss: 1.8716 | acc: 0.4719 | Val loss: 1.8872 | Val acc: 0.4808
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 4.85s | loss: 1.4735 | acc: 0.7256 | Val loss: 1.4707 | Val acc: 0.7264
#
# *************************** Total Training Time = 0hr 0mins 9secs 747.83ms ***************************
#
# Sample: 27/60 -- Learning Rate: 0.000218 | Minibatch Size: 1484
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 5.72s | loss: 1.3480 | acc: 0.7534 | Val loss: 1.3390 | Val acc: 0.7608
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 5.70s | loss: 0.7664 | acc: 0.8463 | Val loss: 0.7314 | Val acc: 0.8616
#
# *************************** Total Training Time = 0hr 0mins 11secs 480.53ms ***************************
#
# Sample: 28/60 -- Learning Rate: 0.017863 | Minibatch Size: 1479
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 5.22s | loss: 0.6678 | acc: 0.7960 | Val loss: 0.6530 | Val acc: 0.8072
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 5.17s | loss: 0.3011 | acc: 0.9104 | Val loss: 0.2816 | Val acc: 0.9144
#
# *************************** Total Training Time = 0hr 0mins 10secs 442.37ms ***************************
#
# Sample: 29/60 -- Learning Rate: 0.034783 | Minibatch Size: 1020
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 6.69s | loss: 0.7790 | acc: 0.7423 | Val loss: 0.7558 | Val acc: 0.7560
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 6.71s | loss: 0.3917 | acc: 0.8811 | Val loss: 0.3877 | Val acc: 0.8840
#
# *************************** Total Training Time = 0hr 0mins 13secs 458.34ms ***************************
#
# Sample: 30/60 -- Learning Rate: 0.001521 | Minibatch Size: 1160
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 6.47s | loss: 0.3399 | acc: 0.9027 | Val loss: 0.3164 | Val acc: 0.9096
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 6.39s | loss: 0.2140 | acc: 0.9388 | Val loss: 0.2235 | Val acc: 0.9400
#
# *************************** Total Training Time = 0hr 0mins 12secs 922.96ms ***************************
#
# Sample: 31/60 -- Learning Rate: 0.039775 | Minibatch Size: 2191
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 3.60s | loss: 1.6221 | acc: 0.4371 | Val loss: 1.5532 | Val acc: 0.4504 6
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 3.55s | loss: 1.0798 | acc: 0.5984 | Val loss: 1.0236 | Val acc: 0.6256
#
# *************************** Total Training Time = 0hr 0mins 7secs 209.89ms ***************************
#
# Sample: 32/60 -- Learning Rate: 0.001411 | Minibatch Size: 1992
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 4.38s | loss: 0.4382 | acc: 0.8745 | Val loss: 0.3995 | Val acc: 0.8800
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 4.25s | loss: 0.3042 | acc: 0.9149 | Val loss: 0.2999 | Val acc: 0.9128
#
# *************************** Total Training Time = 0hr 0mins 8secs 686.76ms ***************************
#
# Sample: 33/60 -- Learning Rate: 0.001022 | Minibatch Size: 105
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 62.57s | loss: 0.1644 | acc: 0.9520 | Val loss: 0.1968 | Val acc: 0.9448
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 62.66s | loss: 0.0745 | acc: 0.9801 | Val loss: 0.1224 | Val acc: 0.9656
#
# *************************** Total Training Time = 0hr 2mins 5secs 320.31ms ***************************
#
# Sample: 34/60 -- Learning Rate: 0.006368 | Minibatch Size: 1814
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 4.55s | loss: 0.4960 | acc: 0.8451 | Val loss: 0.4538 | Val acc: 0.8648
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 4.53s | loss: 0.3021 | acc: 0.9133 | Val loss: 0.2947 | Val acc: 0.9120
#
# *************************** Total Training Time = 0hr 0mins 9secs 135.22ms ***************************
#
# Sample: 35/60 -- Learning Rate: 0.037837 | Minibatch Size: 810
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 8.20s | loss: 0.4864 | acc: 0.8691 | Val loss: 0.4981 | Val acc: 0.8736
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 8.19s | loss: 0.2735 | acc: 0.9171 | Val loss: 0.2851 | Val acc: 0.9184
#
# *************************** Total Training Time = 0hr 0mins 16secs 450.34ms ***************************
#
# Sample: 36/60 -- Learning Rate: 0.001981 | Minibatch Size: 1298
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 6.02s | loss: 0.3543 | acc: 0.8983 | Val loss: 0.3312 | Val acc: 0.9064
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 5.96s | loss: 0.2225 | acc: 0.9358 | Val loss: 0.2355 | Val acc: 0.9368
#
# *************************** Total Training Time = 0hr 0mins 12secs 30.95ms ***************************
#
# Sample: 37/60 -- Learning Rate: 0.009011 | Minibatch Size: 793
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 8.43s | loss: 0.3390 | acc: 0.8960 | Val loss: 0.3268 | Val acc: 0.9064
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 8.43s | loss: 0.1571 | acc: 0.9525 | Val loss: 0.1798 | Val acc: 0.9520
#
# *************************** Total Training Time = 0hr 0mins 16secs 923.31ms ***************************
#
# Sample: 38/60 -- Learning Rate: 0.039675 | Minibatch Size: 1524
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 4.73s | loss: 1.3943 | acc: 0.4759 | Val loss: 1.3571 | Val acc: 0.5048
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 4.71s | loss: 0.6517 | acc: 0.8267 | Val loss: 0.6243 | Val acc: 0.8464
#
# *************************** Total Training Time = 0hr 0mins 9secs 496.01ms ***************************
#
# Sample: 39/60 -- Learning Rate: 0.002696 | Minibatch Size: 262
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 25.12s | loss: 0.1341 | acc: 0.9611 | Val loss: 0.1595 | Val acc: 0.9552
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 25.90s | loss: 0.0730 | acc: 0.9786 | Val loss: 0.1217 | Val acc: 0.9648
#
# *************************** Total Training Time = 0hr 0mins 51secs 86.79ms ***************************
#
# Sample: 40/60 -- Learning Rate: 0.000876 | Minibatch Size: 1045
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 7.36s | loss: 0.3681 | acc: 0.8942 | Val loss: 0.3349 | Val acc: 0.9056
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 7.28s | loss: 0.2455 | acc: 0.9301 | Val loss: 0.2485 | Val acc: 0.9336
#
# *************************** Total Training Time = 0hr 0mins 14secs 696.92ms ***************************
#
# Sample: 41/60 -- Learning Rate: 0.000865 | Minibatch Size: 1938
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 4.39s | loss: 0.5959 | acc: 0.8540 | Val loss: 0.5552 | Val acc: 0.8816
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 4.34s | loss: 0.3430 | acc: 0.9028 | Val loss: 0.3140 | Val acc: 0.9112
#
# *************************** Total Training Time = 0hr 0mins 8secs 785.16ms ***************************
#
# Sample: 42/60 -- Learning Rate: 0.000153 | Minibatch Size: 1187
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 6.59s | loss: 1.4839 | acc: 0.7173 | Val loss: 1.4816 | Val acc: 0.7232
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 6.55s | loss: 0.9057 | acc: 0.8322 | Val loss: 0.8765 | Val acc: 0.8448
#
# *************************** Total Training Time = 0hr 0mins 13secs 196.01ms ***************************
#
# Sample: 43/60 -- Learning Rate: 0.000437 | Minibatch Size: 1754
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 4.83s | loss: 0.9660 | acc: 0.8195 | Val loss: 0.9353 | Val acc: 0.8344
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 4.80s | loss: 0.4763 | acc: 0.8791 | Val loss: 0.4392 | Val acc: 0.8992
#
# *************************** Total Training Time = 0hr 0mins 9secs 680.11ms ***************************
#
# Sample: 44/60 -- Learning Rate: 0.009580 | Minibatch Size: 502
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 12.71s | loss: 0.2259 | acc: 0.9322 | Val loss: 0.2280 | Val acc: 0.9336
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 12.77s | loss: 0.1293 | acc: 0.9608 | Val loss: 0.1641 | Val acc: 0.9552
#
# *************************** Total Training Time = 0hr 0mins 25secs 545.38ms ***************************
#
# Sample: 45/60 -- Learning Rate: 0.006343 | Minibatch Size: 792
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 8.64s | loss: 0.2731 | acc: 0.9224 | Val loss: 0.2583 | Val acc: 0.9320
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 8.57s | loss: 0.1459 | acc: 0.9576 | Val loss: 0.1649 | Val acc: 0.9544
#
# *************************** Total Training Time = 0hr 0mins 17secs 270.07ms ***************************
#
# Sample: 46/60 -- Learning Rate: 0.010392 | Minibatch Size: 726
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 9.16s | loss: 0.3151 | acc: 0.9089 | Val loss: 0.3242 | Val acc: 0.9048
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 9.11s | loss: 0.1646 | acc: 0.9497 | Val loss: 0.1832 | Val acc: 0.9488
#
# *************************** Total Training Time = 0hr 0mins 18secs 331.57ms ***************************
#
# Sample: 47/60 -- Learning Rate: 0.053756 | Minibatch Size: 366
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 16.71s | loss: 0.4657 | acc: 0.8760 | Val loss: 0.4802 | Val acc: 0.8712
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 16.56s | loss: 0.3048 | acc: 0.9103 | Val loss: 0.3477 | Val acc: 0.9088
#
# *************************** Total Training Time = 0hr 0mins 33secs 336.89ms ***************************
#
# Sample: 48/60 -- Learning Rate: 0.000979 | Minibatch Size: 840
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 8.56s | loss: 0.3258 | acc: 0.9059 | Val loss: 0.3066 | Val acc: 0.9120
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 8.45s | loss: 0.2117 | acc: 0.9401 | Val loss: 0.2182 | Val acc: 0.9408
#
# *************************** Total Training Time = 0hr 0mins 17secs 65.17ms ***************************
#
# Sample: 49/60 -- Learning Rate: 0.004712 | Minibatch Size: 1654
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 5.04s | loss: 0.4425 | acc: 0.8698 | Val loss: 0.4016 | Val acc: 0.8944
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 5.58s | loss: 0.2687 | acc: 0.9189 | Val loss: 0.2588 | Val acc: 0.9280
#
# *************************** Total Training Time = 0hr 0mins 10secs 676.97ms ***************************
#
# Sample: 50/60 -- Learning Rate: 0.000953 | Minibatch Size: 1586
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 5.33s | loss: 0.4542 | acc: 0.8765 | Val loss: 0.4149 | Val acc: 0.8848
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 5.14s | loss: 0.2997 | acc: 0.9150 | Val loss: 0.2887 | Val acc: 0.9184
#
# *************************** Total Training Time = 0hr 0mins 10secs 528.55ms ***************************
#
# Sample: 51/60 -- Learning Rate: 0.000116 | Minibatch Size: 163
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 39.97s | loss: 0.4498 | acc: 0.8905 | Val loss: 0.4180 | Val acc: 0.9104
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 39.51s | loss: 0.2910 | acc: 0.9257 | Val loss: 0.2783 | Val acc: 0.9312
#
# *************************** Total Training Time = 0hr 1mins 19secs 557.33ms ***************************
#
# Sample: 52/60 -- Learning Rate: 0.000649 | Minibatch Size: 202
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 32.62s | loss: 0.2171 | acc: 0.9388 | Val loss: 0.2335 | Val acc: 0.9368
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 32.40s | loss: 0.1384 | acc: 0.9615 | Val loss: 0.1729 | Val acc: 0.9520
#
# *************************** Total Training Time = 0hr 1mins 5secs 102.39ms ***************************
#
# Sample: 53/60 -- Learning Rate: 0.003210 | Minibatch Size: 968
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 7.58s | loss: 0.2917 | acc: 0.9179 | Val loss: 0.2817 | Val acc: 0.9224
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 7.55s | loss: 0.1586 | acc: 0.9543 | Val loss: 0.1708 | Val acc: 0.9496
#
# *************************** Total Training Time = 0hr 0mins 15secs 186.59ms ***************************
#
# Sample: 54/60 -- Learning Rate: 0.002718 | Minibatch Size: 1864
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 4.74s | loss: 0.4285 | acc: 0.8802 | Val loss: 0.3844 | Val acc: 0.9008
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 4.70s | loss: 0.3407 | acc: 0.8973 | Val loss: 0.3261 | Val acc: 0.9032
#
# *************************** Total Training Time = 0hr 0mins 9secs 503.02ms ***************************
#
# Sample: 55/60 -- Learning Rate: 0.000231 | Minibatch Size: 704
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 10.40s | loss: 0.7589 | acc: 0.8419 | Val loss: 0.7236 | Val acc: 0.8640
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 10.37s | loss: 0.3881 | acc: 0.8994 | Val loss: 0.3589 | Val acc: 0.9096
#
# *************************** Total Training Time = 0hr 0mins 20secs 832.15ms ***************************
#
# Sample: 56/60 -- Learning Rate: 0.000392 | Minibatch Size: 1227
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 7.26s | loss: 0.7598 | acc: 0.8387 | Val loss: 0.7225 | Val acc: 0.8680
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 6.47s | loss: 0.3877 | acc: 0.8945 | Val loss: 0.3569 | Val acc: 0.9056
#
# *************************** Total Training Time = 0hr 0mins 13secs 788.42ms ***************************
#
# Sample: 57/60 -- Learning Rate: 0.000149 | Minibatch Size: 1255
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 6.14s | loss: 1.5552 | acc: 0.6887 | Val loss: 1.5565 | Val acc: 0.6928
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 6.14s | loss: 0.9946 | acc: 0.8217 | Val loss: 0.9690 | Val acc: 0.8304
#
# *************************** Total Training Time = 0hr 0mins 12secs 338.42ms ***************************
#
# Sample: 58/60 -- Learning Rate: 0.054011 | Minibatch Size: 1313
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 5.93s | loss: 1.5057 | acc: 0.4120 | Val loss: 1.4758 | Val acc: 0.4272
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 5.50s | loss: 0.9815 | acc: 0.6611 | Val loss: 0.9938 | Val acc: 0.6824
#
# *************************** Total Training Time = 0hr 0mins 11secs 485.38ms ***************************
#
# Sample: 59/60 -- Learning Rate: 0.000105 | Minibatch Size: 482
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 14.64s | loss: 1.0988 | acc: 0.8097 | Val loss: 1.0767 | Val acc: 0.8216
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 14.79s | loss: 0.5659 | acc: 0.8769 | Val loss: 0.5309 | Val acc: 0.8904
#
# *************************** Total Training Time = 0hr 0mins 29secs 496.04ms ***************************
#
# Sample: 60/60 -- Learning Rate: 0.077871 | Minibatch Size: 1772
# ==========================================================================================================
#
# Epoch: 1/2
# 15000/15000 [==========> 100%] - 4.08s | loss: nan | acc: 0.0977 | Val loss: nan | Val acc: 0.0840
# Epoch: 2/2
# 15000/15000 [==========> 100%] - 4.19s | loss: nan | acc: 0.0977 | Val loss: nan | Val acc: 0.0840
#
# *************************** Total Training Time = 0hr 0mins 8secs 326.68ms ***************************
# ==========================================================================================================
#
#
# *************************** Total Search Time = 0hr 26mins 22secs 870.54ms ***************************
#
#
# Coarse Search Summary for Hyper Parameters with high Accuracy:
#
# +================+===============+================+
# | Validation Acc | Learning Rate | Minibatch Size |
# +================+===============+================+
# | 0.91040	 | 0.03788	 | 117		  |
# | 0.93200	 | 0.00445	 | 1000		  |
# | 0.95520	 | 0.00205	 | 153		  |
# | 0.95680	 | 0.00425	 | 150		  |
# | 0.94160	 | 0.00599	 | 780		  |
# | 0.91920	 | 0.00135	 | 1279		  |
# | 0.94080	 | 0.00532	 | 790		  |
# | 0.92080	 | 0.00067	 | 579		  |
# | 0.94000	 | 0.00828	 | 492		  |
# | 0.90640	 | 0.00167	 | 1989		  |
# | 0.95120	 | 0.00111	 | 187		  |
# | 0.90160	 | 0.01786	 | 1479		  |
# | 0.92240	 | 0.00152	 | 1160		  |
# | 0.90800	 | 0.00141	 | 1992		  |
# | 0.95760	 | 0.00102	 | 105		  |
# | 0.90480	 | 0.00637	 | 1814		  |
# | 0.90560	 | 0.03784	 | 810		  |
# | 0.92560	 | 0.00198	 | 1298		  |
# | 0.93680	 | 0.00901	 | 793		  |
# | 0.95600	 | 0.00270	 | 262		  |
# | 0.91280	 | 0.00088	 | 1045		  |
# | 0.94880	 | 0.00958	 | 502		  |
# | 0.94240	 | 0.00634	 | 792		  |
# | 0.93760	 | 0.01039	 | 726		  |
# | 0.91920	 | 0.00098	 | 840		  |
# | 0.90960	 | 0.00471	 | 1654		  |
# | 0.90560	 | 0.00095	 | 1586		  |
# | 0.91280	 | 0.00012	 | 163		  |
# | 0.93840	 | 0.00065	 | 202		  |
# | 0.93680	 | 0.00321	 | 968		  |
# +================+===============+================+
# New Search Space for Learning Rate: [0.000096,0.039885]
# New Search Space for Minibatch Size: [85,2012]
# Best Score: 0.957600
# Best Hyper Params:
#  Learning Rate: 0.001022
#  Minibatch Size: 105

# %%
#Fine Random Search

param1_fine = {"hParam type": "learning_rate" ,
          "hParam range": lr_rng_fine }
    
param2_fine = {"hParam type": "minibatch_size",
          "hParam range": mbs_rng_fine } 
    
lr_rng_detail, mbs_rng_detail, best_comb = random_search_2D(param1 = param1_fine, param2 = param2_fine , search_type ="fine", evaluate_metric = "test_acc", sample_size = 30, summary = True)
# Out:
# Sample: 1/30 -- Learning Rate: 0.002313 | Minibatch Size: 1216
# ==========================================================================================================
#
# Epoch: 1/5
# 15000/15000 [==========> 100%] - 5.74s | loss: 0.3574 | acc: 0.8977 | Val loss: 0.3544 | Val acc: 0.8976
# Epoch: 2/5
# 15000/15000 [==========> 100%] - 6.30s | loss: 0.1891 | acc: 0.9443 | Val loss: 0.2065 | Val acc: 0.9440
# Epoch: 3/5
# 15000/15000 [==========> 100%] - 6.17s | loss: 0.1296 | acc: 0.9637 | Val loss: 0.1604 | Val acc: 0.9616
# Epoch: 4/5
# 15000/15000 [==========> 100%] - 7.40s | loss: 0.0902 | acc: 0.9744 | Val loss: 0.1416 | Val acc: 0.9592
# Epoch: 5/5
# 15000/15000 [==========> 100%] - 7.89s | loss: 0.0621 | acc: 0.9829 | Val loss: 0.1216 | Val acc: 0.9688
#
# *************************** Total Training Time = 0hr 0mins 33secs 646.35ms ***************************
#
# Sample: 2/30 -- Learning Rate: 0.002382 | Minibatch Size: 1253
# ==========================================================================================================
#
# Epoch: 1/5
# 15000/15000 [==========> 100%] - 7.32s | loss: 0.3447 | acc: 0.9013 | Val loss: 0.3424 | Val acc: 0.9104
# Epoch: 2/5
# 15000/15000 [==========> 100%] - 7.30s | loss: 0.1918 | acc: 0.9444 | Val loss: 0.2118 | Val acc: 0.9424
# Epoch: 3/5
# 15000/15000 [==========> 100%] - 7.22s | loss: 0.1301 | acc: 0.9634 | Val loss: 0.1699 | Val acc: 0.9560
# Epoch: 4/5
# 15000/15000 [==========> 100%] - 7.26s | loss: 0.0913 | acc: 0.9753 | Val loss: 0.1436 | Val acc: 0.9592
# Epoch: 5/5
# 15000/15000 [==========> 100%] - 7.27s | loss: 0.0650 | acc: 0.9829 | Val loss: 0.1326 | Val acc: 0.9624
#
# *************************** Total Training Time = 0hr 0mins 36secs 545.34ms ***************************
#
# Sample: 3/30 -- Learning Rate: 0.002348 | Minibatch Size: 1225
# ==========================================================================================================
#
# Epoch: 1/5
# 15000/15000 [==========> 100%] - 7.75s | loss: 0.3215 | acc: 0.9069 | Val loss: 0.3192 | Val acc: 0.9080
# Epoch: 2/5
# 15000/15000 [==========> 100%] - 7.63s | loss: 0.1954 | acc: 0.9425 | Val loss: 0.2104 | Val acc: 0.9416
# Epoch: 3/5
# 15000/15000 [==========> 100%] - 7.55s | loss: 0.1265 | acc: 0.9652 | Val loss: 0.1625 | Val acc: 0.9584
# Epoch: 4/5
# 15000/15000 [==========> 100%] - 7.65s | loss: 0.0923 | acc: 0.9733 | Val loss: 0.1453 | Val acc: 0.9616
# Epoch: 5/5
# 15000/15000 [==========> 100%] - 7.20s | loss: 0.0641 | acc: 0.9823 | Val loss: 0.1337 | Val acc: 0.9640
#
# *************************** Total Training Time = 0hr 0mins 37secs 939.72ms ***************************
#
# Sample: 4/30 -- Learning Rate: 0.002389 | Minibatch Size: 1218
# ==========================================================================================================
#
# Epoch: 1/5
# 15000/15000 [==========> 100%] - 7.35s | loss: 0.3276 | acc: 0.9065 | Val loss: 0.3253 | Val acc: 0.9080
# Epoch: 2/5
# 15000/15000 [==========> 100%] - 6.97s | loss: 0.1951 | acc: 0.9427 | Val loss: 0.2115 | Val acc: 0.9368
# Epoch: 3/5
# 15000/15000 [==========> 100%] - 7.02s | loss: 0.1254 | acc: 0.9659 | Val loss: 0.1628 | Val acc: 0.9592
# Epoch: 4/5
# 15000/15000 [==========> 100%] - 6.64s | loss: 0.0893 | acc: 0.9745 | Val loss: 0.1426 | Val acc: 0.9616
# Epoch: 5/5
# 15000/15000 [==========> 100%] - 6.64s | loss: 0.0635 | acc: 0.9824 | Val loss: 0.1320 | Val acc: 0.9640
#
# *************************** Total Training Time = 0hr 0mins 34secs 754.02ms ***************************
#
# Sample: 5/30 -- Learning Rate: 0.002296 | Minibatch Size: 1227
# ==========================================================================================================
#
# Epoch: 1/5
# 15000/15000 [==========> 100%] - 6.57s | loss: 0.3181 | acc: 0.9089 | Val loss: 0.3164 | Val acc: 0.9136
# Epoch: 2/5
# 15000/15000 [==========> 100%] - 6.58s | loss: 0.1955 | acc: 0.9421 | Val loss: 0.2092 | Val acc: 0.9432
# Epoch: 3/5
# 15000/15000 [==========> 100%] - 6.68s | loss: 0.1301 | acc: 0.9643 | Val loss: 0.1648 | Val acc: 0.9592
# Epoch: 4/5
# 15000/15000 [==========> 100%] - 6.65s | loss: 0.0931 | acc: 0.9729 | Val loss: 0.1466 | Val acc: 0.9592
# Epoch: 5/5
# 15000/15000 [==========> 100%] - 6.63s | loss: 0.0647 | acc: 0.9819 | Val loss: 0.1321 | Val acc: 0.9632
#
# *************************** Total Training Time = 0hr 0mins 33secs 249.84ms ***************************
#
# Sample: 6/30 -- Learning Rate: 0.002294 | Minibatch Size: 1236
# ==========================================================================================================
#
# Epoch: 1/5
# 15000/15000 [==========> 100%] - 6.56s | loss: 0.3456 | acc: 0.8993 | Val loss: 0.3386 | Val acc: 0.9088
# Epoch: 2/5
# 15000/15000 [==========> 100%] - 6.55s | loss: 0.2177 | acc: 0.9353 | Val loss: 0.2179 | Val acc: 0.9352
# Epoch: 3/5
# 15000/15000 [==========> 100%] - 6.72s | loss: 0.1333 | acc: 0.9634 | Val loss: 0.1765 | Val acc: 0.9560
# Epoch: 4/5
# 15000/15000 [==========> 100%] - 6.62s | loss: 0.0944 | acc: 0.9725 | Val loss: 0.1440 | Val acc: 0.9608
# Epoch: 5/5
# 15000/15000 [==========> 100%] - 6.64s | loss: 0.0696 | acc: 0.9806 | Val loss: 0.1357 | Val acc: 0.9616
#
# *************************** Total Training Time = 0hr 0mins 33secs 229.52ms ***************************
#
# Sample: 7/30 -- Learning Rate: 0.002164 | Minibatch Size: 1229
# ==========================================================================================================
#
# Epoch: 1/5
# 15000/15000 [==========> 100%] - 6.56s | loss: 0.3176 | acc: 0.9076 | Val loss: 0.3156 | Val acc: 0.9192
# Epoch: 2/5
# 15000/15000 [==========> 100%] - 6.61s | loss: 0.1926 | acc: 0.9435 | Val loss: 0.2034 | Val acc: 0.9456
# Epoch: 3/5
# 15000/15000 [==========> 100%] - 6.61s | loss: 0.1364 | acc: 0.9618 | Val loss: 0.1727 | Val acc: 0.9552
# Epoch: 4/5
# 15000/15000 [==========> 100%] - 6.62s | loss: 0.0957 | acc: 0.9722 | Val loss: 0.1477 | Val acc: 0.9576
# Epoch: 5/5
# 15000/15000 [==========> 100%] - 6.63s | loss: 0.0703 | acc: 0.9803 | Val loss: 0.1384 | Val acc: 0.9640
#
# *************************** Total Training Time = 0hr 0mins 33secs 175.24ms ***************************
#
# Sample: 8/30 -- Learning Rate: 0.002060 | Minibatch Size: 1236
# ==========================================================================================================
#
# Epoch: 1/5
# 15000/15000 [==========> 100%] - 6.55s | loss: 0.3387 | acc: 0.9001 | Val loss: 0.3269 | Val acc: 0.9136
# Epoch: 2/5
# 15000/15000 [==========> 100%] - 6.54s | loss: 0.2191 | acc: 0.9354 | Val loss: 0.2185 | Val acc: 0.9408
# Epoch: 3/5
# 15000/15000 [==========> 100%] - 6.58s | loss: 0.1421 | acc: 0.9594 | Val loss: 0.1830 | Val acc: 0.9528
# Epoch: 4/5
# 15000/15000 [==========> 100%] - 6.61s | loss: 0.1013 | acc: 0.9703 | Val loss: 0.1487 | Val acc: 0.9608
# Epoch: 5/5
# 15000/15000 [==========> 100%] - 6.63s | loss: 0.0754 | acc: 0.9795 | Val loss: 0.1390 | Val acc: 0.9624
#
# *************************** Total Training Time = 0hr 0mins 33secs 43.16ms ***************************
#
# Sample: 9/30 -- Learning Rate: 0.002116 | Minibatch Size: 1243
# ==========================================================================================================
#
# Epoch: 1/5
# 15000/15000 [==========> 100%] - 6.60s | loss: 0.3533 | acc: 0.8973 | Val loss: 0.3442 | Val acc: 0.9096
# Epoch: 2/5
# 15000/15000 [==========> 100%] - 6.54s | loss: 0.2400 | acc: 0.9276 | Val loss: 0.2376 | Val acc: 0.9320
# Epoch: 3/5
# 15000/15000 [==========> 100%] - 6.56s | loss: 0.1547 | acc: 0.9549 | Val loss: 0.1954 | Val acc: 0.9512
# Epoch: 4/5
# 15000/15000 [==========> 100%] - 6.64s | loss: 0.1096 | acc: 0.9689 | Val loss: 0.1570 | Val acc: 0.9600
# Epoch: 5/5
# 15000/15000 [==========> 100%] - 6.65s | loss: 0.0862 | acc: 0.9757 | Val loss: 0.1457 | Val acc: 0.9600
#
# *************************** Total Training Time = 0hr 0mins 33secs 130.96ms ***************************
#
# Sample: 10/30 -- Learning Rate: 0.002299 | Minibatch Size: 1224
# ==========================================================================================================
#
# Epoch: 1/5
# 15000/15000 [==========> 100%] - 6.56s | loss: 0.3178 | acc: 0.9083 | Val loss: 0.3159 | Val acc: 0.9136
# Epoch: 2/5
# 15000/15000 [==========> 100%] - 6.57s | loss: 0.1968 | acc: 0.9420 | Val loss: 0.2110 | Val acc: 0.9400
# Epoch: 3/5
# 15000/15000 [==========> 100%] - 6.55s | loss: 0.1271 | acc: 0.9649 | Val loss: 0.1626 | Val acc: 0.9608
# Epoch: 4/5
# 15000/15000 [==========> 100%] - 6.57s | loss: 0.0913 | acc: 0.9739 | Val loss: 0.1439 | Val acc: 0.9640
# Epoch: 5/5
# 15000/15000 [==========> 100%] - 6.60s | loss: 0.0638 | acc: 0.9815 | Val loss: 0.1314 | Val acc: 0.9632
#
# *************************** Total Training Time = 0hr 0mins 32secs 998.16ms ***************************
#
# Sample: 11/30 -- Learning Rate: 0.002055 | Minibatch Size: 1238
# ==========================================================================================================
#
# Epoch: 1/5
# 15000/15000 [==========> 100%] - 6.51s | loss: 0.3479 | acc: 0.8972 | Val loss: 0.3321 | Val acc: 0.9120
# Epoch: 2/5
# 15000/15000 [==========> 100%] - 6.49s | loss: 0.2190 | acc: 0.9353 | Val loss: 0.2216 | Val acc: 0.9392
# Epoch: 3/5
# 15000/15000 [==========> 100%] - 6.54s | loss: 0.1420 | acc: 0.9591 | Val loss: 0.1839 | Val acc: 0.9520
# Epoch: 4/5
# 15000/15000 [==========> 100%] - 6.57s | loss: 0.0992 | acc: 0.9711 | Val loss: 0.1458 | Val acc: 0.9600
# Epoch: 5/5
# 15000/15000 [==========> 100%] - 6.60s | loss: 0.0778 | acc: 0.9783 | Val loss: 0.1409 | Val acc: 0.9616
#
# *************************** Total Training Time = 0hr 0mins 32secs 838.20ms ***************************
#
# Sample: 12/30 -- Learning Rate: 0.002080 | Minibatch Size: 1226
# ==========================================================================================================
#
# Epoch: 1/5
# 15000/15000 [==========> 100%] - 6.51s | loss: 0.3122 | acc: 0.9098 | Val loss: 0.3074 | Val acc: 0.9160
# Epoch: 2/5
# 15000/15000 [==========> 100%] - 6.50s | loss: 0.2012 | acc: 0.9414 | Val loss: 0.2130 | Val acc: 0.9448
# Epoch: 3/5
# 15000/15000 [==========> 100%] - 6.52s | loss: 0.1375 | acc: 0.9626 | Val loss: 0.1682 | Val acc: 0.9552
# Epoch: 4/5
# 15000/15000 [==========> 100%] - 6.60s | loss: 0.0981 | acc: 0.9717 | Val loss: 0.1499 | Val acc: 0.9568
# Epoch: 5/5
# 15000/15000 [==========> 100%] - 6.74s | loss: 0.0694 | acc: 0.9805 | Val loss: 0.1352 | Val acc: 0.9624
#
# *************************** Total Training Time = 0hr 0mins 33secs 14.72ms ***************************
#
# Sample: 13/30 -- Learning Rate: 0.002317 | Minibatch Size: 1229
# ==========================================================================================================
#
# Epoch: 1/5
# 15000/15000 [==========> 100%] - 6.52s | loss: 0.3241 | acc: 0.9064 | Val loss: 0.3237 | Val acc: 0.9120
# Epoch: 2/5
# 15000/15000 [==========> 100%] - 6.51s | loss: 0.1935 | acc: 0.9447 | Val loss: 0.2053 | Val acc: 0.9392
# Epoch: 3/5
# 15000/15000 [==========> 100%] - 6.55s | loss: 0.1301 | acc: 0.9639 | Val loss: 0.1704 | Val acc: 0.9560
# Epoch: 4/5
# 15000/15000 [==========> 100%] - 6.59s | loss: 0.0926 | acc: 0.9737 | Val loss: 0.1459 | Val acc: 0.9624
# Epoch: 5/5
# 15000/15000 [==========> 100%] - 6.58s | loss: 0.0664 | acc: 0.9813 | Val loss: 0.1362 | Val acc: 0.9632
#
# *************************** Total Training Time = 0hr 0mins 32secs 897.04ms ***************************
#
# Sample: 14/30 -- Learning Rate: 0.002174 | Minibatch Size: 1251
# ==========================================================================================================
#
# Epoch: 1/5
# 15000/15000 [==========> 100%] - 6.24s | loss: 0.3383 | acc: 0.9022 | Val loss: 0.3298 | Val acc: 0.9152
# Epoch: 2/5
# 15000/15000 [==========> 100%] - 6.07s | loss: 0.1960 | acc: 0.9441 | Val loss: 0.2136 | Val acc: 0.9424
# Epoch: 3/5
# 15000/15000 [==========> 100%] - 6.10s | loss: 0.1361 | acc: 0.9611 | Val loss: 0.1747 | Val acc: 0.9552
# Epoch: 4/5
# 15000/15000 [==========> 100%] - 6.12s | loss: 0.0936 | acc: 0.9734 | Val loss: 0.1445 | Val acc: 0.9616
# Epoch: 5/5
# 15000/15000 [==========> 100%] - 6.15s | loss: 0.0654 | acc: 0.9827 | Val loss: 0.1320 | Val acc: 0.9624
#
# *************************** Total Training Time = 0hr 0mins 30secs 820.98ms ***************************
#
# Sample: 15/30 -- Learning Rate: 0.002201 | Minibatch Size: 1246
# ==========================================================================================================
#
# Epoch: 1/5
# 15000/15000 [==========> 100%] - 6.53s | loss: 0.4041 | acc: 0.8809 | Val loss: 0.3939 | Val acc: 0.8896
# Epoch: 2/5
# 15000/15000 [==========> 100%] - 6.54s | loss: 0.2957 | acc: 0.9113 | Val loss: 0.2873 | Val acc: 0.9168
# Epoch: 3/5
# 15000/15000 [==========> 100%] - 6.57s | loss: 0.1762 | acc: 0.9497 | Val loss: 0.1967 | Val acc: 0.9488
# Epoch: 4/5
# 15000/15000 [==========> 100%] - 6.61s | loss: 0.1264 | acc: 0.9651 | Val loss: 0.1648 | Val acc: 0.9520
# Epoch: 5/5
# 15000/15000 [==========> 100%] - 6.65s | loss: 0.0973 | acc: 0.9721 | Val loss: 0.1477 | Val acc: 0.9600
#
# *************************** Total Training Time = 0hr 0mins 33secs 51.77ms ***************************
#
# Sample: 16/30 -- Learning Rate: 0.002338 | Minibatch Size: 1218
# ==========================================================================================================
#
# Epoch: 1/5
# 15000/15000 [==========> 100%] - 6.56s | loss: 0.3227 | acc: 0.9080 | Val loss: 0.3189 | Val acc: 0.9088
# Epoch: 2/5
# 15000/15000 [==========> 100%] - 6.53s | loss: 0.1940 | acc: 0.9432 | Val loss: 0.2090 | Val acc: 0.9392
# Epoch: 3/5
# 15000/15000 [==========> 100%] - 6.70s | loss: 0.1267 | acc: 0.9657 | Val loss: 0.1632 | Val acc: 0.9560
# Epoch: 4/5
# 15000/15000 [==========> 100%] - 6.65s | loss: 0.0896 | acc: 0.9748 | Val loss: 0.1434 | Val acc: 0.9616
# Epoch: 5/5
# 15000/15000 [==========> 100%] - 6.61s | loss: 0.0625 | acc: 0.9828 | Val loss: 0.1296 | Val acc: 0.9632
#
# *************************** Total Training Time = 0hr 0mins 33secs 198.08ms ***************************
#
# Sample: 17/30 -- Learning Rate: 0.002056 | Minibatch Size: 1243
# ==========================================================================================================
#
# Epoch: 1/5
# 15000/15000 [==========> 100%] - 6.56s | loss: 0.3493 | acc: 0.8981 | Val loss: 0.3406 | Val acc: 0.9104
# Epoch: 2/5
# 15000/15000 [==========> 100%] - 6.51s | loss: 0.2386 | acc: 0.9285 | Val loss: 0.2364 | Val acc: 0.9312
# Epoch: 3/5
# 15000/15000 [==========> 100%] - 6.53s | loss: 0.1582 | acc: 0.9539 | Val loss: 0.1962 | Val acc: 0.9504
# Epoch: 4/5
# 15000/15000 [==========> 100%] - 6.61s | loss: 0.1116 | acc: 0.9679 | Val loss: 0.1561 | Val acc: 0.9568
# Epoch: 5/5
# 15000/15000 [==========> 100%] - 7.67s | loss: 0.0865 | acc: 0.9757 | Val loss: 0.1448 | Val acc: 0.9600
#
# *************************** Total Training Time = 0hr 0mins 34secs 29.96ms ***************************
#
# Sample: 18/30 -- Learning Rate: 0.002212 | Minibatch Size: 1229
# ==========================================================================================================
#
# Epoch: 1/5
# 15000/15000 [==========> 100%] - 7.52s | loss: 0.3196 | acc: 0.9073 | Val loss: 0.3174 | Val acc: 0.9192
# Epoch: 2/5
# 15000/15000 [==========> 100%] - 7.80s | loss: 0.1924 | acc: 0.9438 | Val loss: 0.2037 | Val acc: 0.9440
# Epoch: 3/5
# 15000/15000 [==========> 100%] - 7.63s | loss: 0.1350 | acc: 0.9617 | Val loss: 0.1720 | Val acc: 0.9560
# Epoch: 4/5
# 15000/15000 [==========> 100%] - 6.76s | loss: 0.0944 | acc: 0.9732 | Val loss: 0.1475 | Val acc: 0.9576
# Epoch: 5/5
# 15000/15000 [==========> 100%] - 6.66s | loss: 0.0684 | acc: 0.9809 | Val loss: 0.1361 | Val acc: 0.9624
#
# *************************** Total Training Time = 0hr 0mins 36secs 541.07ms ***************************
#
# Sample: 19/30 -- Learning Rate: 0.002347 | Minibatch Size: 1252
# ==========================================================================================================
#
# Epoch: 1/5
# 15000/15000 [==========> 100%] - 6.16s | loss: 0.3412 | acc: 0.9029 | Val loss: 0.3371 | Val acc: 0.9128
# Epoch: 2/5
# 15000/15000 [==========> 100%] - 6.15s | loss: 0.1917 | acc: 0.9449 | Val loss: 0.2112 | Val acc: 0.9432
# Epoch: 3/5
# 15000/15000 [==========> 100%] - 6.17s | loss: 0.1291 | acc: 0.9641 | Val loss: 0.1680 | Val acc: 0.9544
# Epoch: 4/5
# 15000/15000 [==========> 100%] - 6.21s | loss: 0.0924 | acc: 0.9741 | Val loss: 0.1445 | Val acc: 0.9600
# Epoch: 5/5
# 15000/15000 [==========> 100%] - 6.25s | loss: 0.0642 | acc: 0.9831 | Val loss: 0.1322 | Val acc: 0.9624
#
# *************************** Total Training Time = 0hr 0mins 31secs 87.46ms ***************************
#
# Sample: 20/30 -- Learning Rate: 0.002413 | Minibatch Size: 1217
# ==========================================================================================================
#
# Epoch: 1/5
# 15000/15000 [==========> 100%] - 6.57s | loss: 0.3279 | acc: 0.9062 | Val loss: 0.3279 | Val acc: 0.9056
# Epoch: 2/5
# 15000/15000 [==========> 100%] - 6.54s | loss: 0.1956 | acc: 0.9428 | Val loss: 0.2119 | Val acc: 0.9384
# Epoch: 3/5
# 15000/15000 [==========> 100%] - 6.55s | loss: 0.1242 | acc: 0.9658 | Val loss: 0.1619 | Val acc: 0.9576
# Epoch: 4/5
# 15000/15000 [==========> 100%] - 6.60s | loss: 0.0885 | acc: 0.9750 | Val loss: 0.1408 | Val acc: 0.9632
# Epoch: 5/5
# 15000/15000 [==========> 100%] - 6.62s | loss: 0.0608 | acc: 0.9837 | Val loss: 0.1297 | Val acc: 0.9632
#
# *************************** Total Training Time = 0hr 0mins 33secs 29.44ms ***************************
#
# Sample: 21/30 -- Learning Rate: 0.002173 | Minibatch Size: 1233
# ==========================================================================================================
#
# Epoch: 1/5
# 15000/15000 [==========> 100%] - 6.52s | loss: 0.3295 | acc: 0.9043 | Val loss: 0.3225 | Val acc: 0.9168
# Epoch: 2/5
# 15000/15000 [==========> 100%] - 6.55s | loss: 0.2105 | acc: 0.9386 | Val loss: 0.2163 | Val acc: 0.9368
# Epoch: 3/5
# 15000/15000 [==========> 100%] - 6.56s | loss: 0.1342 | acc: 0.9611 | Val loss: 0.1727 | Val acc: 0.9544
# Epoch: 4/5
# 15000/15000 [==========> 100%] - 6.60s | loss: 0.0978 | acc: 0.9718 | Val loss: 0.1493 | Val acc: 0.9576
# Epoch: 5/5
# 15000/15000 [==========> 100%] - 6.61s | loss: 0.0744 | acc: 0.9783 | Val loss: 0.1385 | Val acc: 0.9616
#
# *************************** Total Training Time = 0hr 0mins 32secs 977.81ms ***************************
#
# Sample: 22/30 -- Learning Rate: 0.002355 | Minibatch Size: 1215
# ==========================================================================================================
#
# Epoch: 1/5
# 15000/15000 [==========> 100%] - 6.54s | loss: 0.3274 | acc: 0.9059 | Val loss: 0.3267 | Val acc: 0.9072
# Epoch: 2/5
# 15000/15000 [==========> 100%] - 6.54s | loss: 0.2014 | acc: 0.9408 | Val loss: 0.2178 | Val acc: 0.9352
# Epoch: 3/5
# 15000/15000 [==========> 100%] - 6.55s | loss: 0.1254 | acc: 0.9657 | Val loss: 0.1605 | Val acc: 0.9600
# Epoch: 4/5
# 15000/15000 [==========> 100%] - 6.60s | loss: 0.0898 | acc: 0.9749 | Val loss: 0.1419 | Val acc: 0.9608
# Epoch: 5/5
# 15000/15000 [==========> 100%] - 6.62s | loss: 0.0625 | acc: 0.9837 | Val loss: 0.1303 | Val acc: 0.9648
#
# *************************** Total Training Time = 0hr 0mins 32secs 992.97ms ***************************
#
# Sample: 23/30 -- Learning Rate: 0.002079 | Minibatch Size: 1241
# ==========================================================================================================
#
# Epoch: 1/5
# 15000/15000 [==========> 100%] - 6.54s | loss: 0.3497 | acc: 0.8977 | Val loss: 0.3375 | Val acc: 0.9080
# Epoch: 2/5
# 15000/15000 [==========> 100%] - 6.50s | loss: 0.2338 | acc: 0.9311 | Val loss: 0.2307 | Val acc: 0.9352
# Epoch: 3/5
# 15000/15000 [==========> 100%] - 6.54s | loss: 0.1533 | acc: 0.9547 | Val loss: 0.1940 | Val acc: 0.9480
# Epoch: 4/5
# 15000/15000 [==========> 100%] - 6.61s | loss: 0.1063 | acc: 0.9702 | Val loss: 0.1494 | Val acc: 0.9624
# Epoch: 5/5
# 15000/15000 [==========> 100%] - 6.59s | loss: 0.0852 | acc: 0.9764 | Val loss: 0.1458 | Val acc: 0.9600
#
# *************************** Total Training Time = 0hr 0mins 32secs 928.10ms ***************************
#
# Sample: 24/30 -- Learning Rate: 0.002106 | Minibatch Size: 1237
# ==========================================================================================================
#
# Epoch: 1/5
# 15000/15000 [==========> 100%] - 6.52s | loss: 0.3415 | acc: 0.9001 | Val loss: 0.3273 | Val acc: 0.9120
# Epoch: 2/5
# 15000/15000 [==========> 100%] - 6.52s | loss: 0.2098 | acc: 0.9382 | Val loss: 0.2165 | Val acc: 0.9408
# Epoch: 3/5
# 15000/15000 [==========> 100%] - 6.55s | loss: 0.1366 | acc: 0.9607 | Val loss: 0.1789 | Val acc: 0.9552
# Epoch: 4/5
# 15000/15000 [==========> 100%] - 6.59s | loss: 0.0975 | acc: 0.9722 | Val loss: 0.1455 | Val acc: 0.9584
# Epoch: 5/5
# 15000/15000 [==========> 100%] - 6.60s | loss: 0.0758 | acc: 0.9778 | Val loss: 0.1404 | Val acc: 0.9600
#
# *************************** Total Training Time = 0hr 0mins 32secs 923.11ms ***************************
#
# Sample: 25/30 -- Learning Rate: 0.002345 | Minibatch Size: 1223
# ==========================================================================================================
#
# Epoch: 1/5
# 15000/15000 [==========> 100%] - 6.55s | loss: 0.3225 | acc: 0.9071 | Val loss: 0.3204 | Val acc: 0.9088
# Epoch: 2/5
# 15000/15000 [==========> 100%] - 6.54s | loss: 0.1959 | acc: 0.9421 | Val loss: 0.2102 | Val acc: 0.9424
# Epoch: 3/5
# 15000/15000 [==========> 100%] - 6.66s | loss: 0.1257 | acc: 0.9647 | Val loss: 0.1614 | Val acc: 0.9600
# Epoch: 4/5
# 15000/15000 [==========> 100%] - 6.61s | loss: 0.0904 | acc: 0.9745 | Val loss: 0.1417 | Val acc: 0.9624
# Epoch: 5/5
# 15000/15000 [==========> 100%] - 6.61s | loss: 0.0641 | acc: 0.9823 | Val loss: 0.1325 | Val acc: 0.9616
#
# *************************** Total Training Time = 0hr 0mins 33secs 108.03ms ***************************
#
# Sample: 26/30 -- Learning Rate: 0.002043 | Minibatch Size: 1218
# ==========================================================================================================
#
# Epoch: 1/5
# 15000/15000 [==========> 100%] - 6.52s | loss: 0.3098 | acc: 0.9116 | Val loss: 0.3030 | Val acc: 0.9184
# Epoch: 2/5
# 15000/15000 [==========> 100%] - 6.51s | loss: 0.1959 | acc: 0.9419 | Val loss: 0.2082 | Val acc: 0.9456
# Epoch: 3/5
# 15000/15000 [==========> 100%] - 6.53s | loss: 0.1365 | acc: 0.9616 | Val loss: 0.1713 | Val acc: 0.9536
# Epoch: 4/5
# 15000/15000 [==========> 100%] - 6.58s | loss: 0.0942 | acc: 0.9743 | Val loss: 0.1456 | Val acc: 0.9592
# Epoch: 5/5
# 15000/15000 [==========> 100%] - 6.59s | loss: 0.0674 | acc: 0.9815 | Val loss: 0.1333 | Val acc: 0.9616
#
# *************************** Total Training Time = 0hr 0mins 32secs 870.94ms ***************************
#
# Sample: 27/30 -- Learning Rate: 0.002077 | Minibatch Size: 1219
# ==========================================================================================================
#
# Epoch: 1/5
# 15000/15000 [==========> 100%] - 6.52s | loss: 0.3099 | acc: 0.9117 | Val loss: 0.3032 | Val acc: 0.9192
# Epoch: 2/5
# 15000/15000 [==========> 100%] - 6.56s | loss: 0.1974 | acc: 0.9419 | Val loss: 0.2096 | Val acc: 0.9456
# Epoch: 3/5
# 15000/15000 [==========> 100%] - 6.95s | loss: 0.1357 | acc: 0.9624 | Val loss: 0.1695 | Val acc: 0.9544
# Epoch: 4/5
# 15000/15000 [==========> 100%] - 6.85s | loss: 0.0946 | acc: 0.9734 | Val loss: 0.1473 | Val acc: 0.9584
# Epoch: 5/5
# 15000/15000 [==========> 100%] - 6.77s | loss: 0.0673 | acc: 0.9814 | Val loss: 0.1347 | Val acc: 0.9616
#
# *************************** Total Training Time = 0hr 0mins 33secs 783.19ms ***************************
#
# Sample: 28/30 -- Learning Rate: 0.002324 | Minibatch Size: 1248
# ==========================================================================================================
#
# Epoch: 1/5
# 15000/15000 [==========> 100%] - 6.75s | loss: 0.3514 | acc: 0.8983 | Val loss: 0.3367 | Val acc: 0.9104
# Epoch: 2/5
# 15000/15000 [==========> 100%] - 7.00s | loss: 0.2490 | acc: 0.9263 | Val loss: 0.2530 | Val acc: 0.9304
# Epoch: 3/5
# 15000/15000 [==========> 100%] - 7.31s | loss: 0.1686 | acc: 0.9499 | Val loss: 0.2068 | Val acc: 0.9416
# Epoch: 4/5
# 15000/15000 [==========> 100%] - 7.04s | loss: 0.1386 | acc: 0.9587 | Val loss: 0.1844 | Val acc: 0.9448
# Epoch: 5/5
# 15000/15000 [==========> 100%] - 7.02s | loss: 0.1109 | acc: 0.9665 | Val loss: 0.1547 | Val acc: 0.9560
#
# *************************** Total Training Time = 0hr 0mins 35secs 271.18ms ***************************
#
# Sample: 29/30 -- Learning Rate: 0.002139 | Minibatch Size: 1217
# ==========================================================================================================
#
# Epoch: 1/5
# 15000/15000 [==========> 100%] - 7.11s | loss: 0.3112 | acc: 0.9112 | Val loss: 0.3079 | Val acc: 0.9176
# Epoch: 2/5
# 15000/15000 [==========> 100%] - 6.59s | loss: 0.1969 | acc: 0.9425 | Val loss: 0.2105 | Val acc: 0.9408
# Epoch: 3/5
# 15000/15000 [==========> 100%] - 6.62s | loss: 0.1336 | acc: 0.9625 | Val loss: 0.1682 | Val acc: 0.9560
# Epoch: 4/5
# 15000/15000 [==========> 100%] - 6.59s | loss: 0.0941 | acc: 0.9735 | Val loss: 0.1478 | Val acc: 0.9592
# Epoch: 5/5
# 15000/15000 [==========> 100%] - 6.62s | loss: 0.0649 | acc: 0.9820 | Val loss: 0.1313 | Val acc: 0.9624
#
# *************************** Total Training Time = 0hr 0mins 33secs 665.81ms ***************************
#
# Sample: 30/30 -- Learning Rate: 0.002142 | Minibatch Size: 1223
# ==========================================================================================================
#
# Epoch: 1/5
# 15000/15000 [==========> 100%] - 6.53s | loss: 0.3139 | acc: 0.9098 | Val loss: 0.3109 | Val acc: 0.9128
# Epoch: 2/5
# 15000/15000 [==========> 100%] - 6.53s | loss: 0.1994 | acc: 0.9411 | Val loss: 0.2127 | Val acc: 0.9440
# Epoch: 3/5
# 15000/15000 [==========> 100%] - 6.55s | loss: 0.1314 | acc: 0.9644 | Val loss: 0.1651 | Val acc: 0.9584
# Epoch: 4/5
# 15000/15000 [==========> 100%] - 6.64s | loss: 0.0950 | acc: 0.9732 | Val loss: 0.1465 | Val acc: 0.9584
# Epoch: 5/5
# 15000/15000 [==========> 100%] - 6.79s | loss: 0.0678 | acc: 0.9806 | Val loss: 0.1338 | Val acc: 0.9616
#
# *************************** Total Training Time = 0hr 0mins 33secs 183.43ms ***************************
# ==========================================================================================================
#
#
# *************************** Total Search Time = 0hr 16mins 48secs 169.67ms ***************************
#
#
# Fine Search Summary for Hyper Parameters with high Accuracy:
#
# +================+===============+================+
# | Validation Acc | Learning Rate | Minibatch Size |
# +================+===============+================+
# | 0.95440	 | 0.00231	 | 1216		  |
# | 0.95760	 | 0.00238	 | 1253		  |
# | 0.95680	 | 0.00235	 | 1225		  |
# | 0.95600	 | 0.00239	 | 1218		  |
# | 0.95680	 | 0.00230	 | 1227		  |
# | 0.95600	 | 0.00229	 | 1236		  |
# | 0.95520	 | 0.00216	 | 1229		  |
# | 0.95440	 | 0.00206	 | 1236		  |
# | 0.96080	 | 0.00230	 | 1224		  |
# | 0.95360	 | 0.00206	 | 1238		  |
# | 0.95520	 | 0.00208	 | 1226		  |
# | 0.95600	 | 0.00232	 | 1229		  |
# | 0.96080	 | 0.00217	 | 1251		  |
# | 0.95280	 | 0.00220	 | 1246		  |
# | 0.95520	 | 0.00234	 | 1218		  |
# | 0.95680	 | 0.00221	 | 1229		  |
# | 0.95920	 | 0.00235	 | 1252		  |
# | 0.95680	 | 0.00241	 | 1217		  |
# | 0.95360	 | 0.00217	 | 1233		  |
# | 0.95200	 | 0.00235	 | 1215		  |
# | 0.95200	 | 0.00208	 | 1241		  |
# | 0.95440	 | 0.00211	 | 1237		  |
# | 0.95520	 | 0.00235	 | 1223		  |
# | 0.96000	 | 0.00204	 | 1218		  |
# | 0.95760	 | 0.00208	 | 1219		  |
# | 0.95920	 | 0.00214	 | 1217		  |
# | 0.95520	 | 0.00214	 | 1223		  |
# +================+===============+================+
# New Search Space for Learning Rate: [0.001843,0.002613]
# New Search Space for Minibatch Size: [1195,1273]
# Best Score: 0.960800
# Best Hyper Params:
#  Learning Rate: 0.002299
#  Minibatch Size: 1224

# %%
#Detail Random Search

param1_detail = {"hParam type": "learning_rate" ,
          "hParam range": lr_rng_detail }
    
param2_detail = {"hParam type": "minibatch_size",
          "hParam range": mbs_rng_detail } 
    
lr_rng_fine, mbs_rng_fine, best_comb = random_search_2D(param1 = param1_detail, param2 = param2_detail , search_type ="detail", evaluate_metric = "test_acc", sample_size = 20, summary = True)
# Out:
# Sample: 1/20 -- Learning Rate: 0.001904 | Minibatch Size: 1200
# ==========================================================================================================
#
# Epoch: 1/10
# 15000/15000 [==========> 100%] - 5.94s | loss: 0.3309 | acc: 0.9029 | Val loss: 0.3062 | Val acc: 0.9136
# Epoch: 2/10
# 15000/15000 [==========> 100%] - 6.53s | loss: 0.2096 | acc: 0.9405 | Val loss: 0.2087 | Val acc: 0.9424
# Epoch: 3/10
# 15000/15000 [==========> 100%] - 6.56s | loss: 0.1627 | acc: 0.9547 | Val loss: 0.1834 | Val acc: 0.9520
# Epoch: 4/10
# 15000/15000 [==========> 100%] - 6.58s | loss: 0.1101 | acc: 0.9707 | Val loss: 0.1481 | Val acc: 0.9560
# Epoch: 5/10
# 15000/15000 [==========> 100%] - 6.60s | loss: 0.0793 | acc: 0.9781 | Val loss: 0.1251 | Val acc: 0.9648
# Epoch: 6/10
# 15000/15000 [==========> 100%] - 6.61s | loss: 0.0575 | acc: 0.9861 | Val loss: 0.1125 | Val acc: 0.9672
# Epoch: 7/10
# 15000/15000 [==========> 100%] - 6.61s | loss: 0.0394 | acc: 0.9912 | Val loss: 0.1088 | Val acc: 0.9672
# Epoch: 8/10
# 15000/15000 [==========> 100%] - 6.59s | loss: 0.0312 | acc: 0.9939 | Val loss: 0.1105 | Val acc: 0.9664
# Epoch: 9/10
# 15000/15000 [==========> 100%] - 6.64s | loss: 0.0241 | acc: 0.9955 | Val loss: 0.1048 | Val acc: 0.9712
# Epoch: 10/10
# 15000/15000 [==========> 100%] - 6.65s | loss: 0.0159 | acc: 0.9982 | Val loss: 0.1018 | Val acc: 0.9664
#
# *************************** Total Training Time = 0hr 1mins 5secs 594.18ms ***************************
#
# Sample: 2/20 -- Learning Rate: 0.002357 | Minibatch Size: 1199
# ==========================================================================================================
#
# Epoch: 1/10
# 15000/15000 [==========> 100%] - 6.58s | loss: 0.3130 | acc: 0.9103 | Val loss: 0.3077 | Val acc: 0.9176
# Epoch: 2/10
# 15000/15000 [==========> 100%] - 6.55s | loss: 0.1966 | acc: 0.9413 | Val loss: 0.2177 | Val acc: 0.9360
# Epoch: 3/10
# 15000/15000 [==========> 100%] - 6.66s | loss: 0.1334 | acc: 0.9619 | Val loss: 0.1632 | Val acc: 0.9576
# Epoch: 4/10
# 15000/15000 [==========> 100%] - 6.64s | loss: 0.0910 | acc: 0.9741 | Val loss: 0.1435 | Val acc: 0.9608
# Epoch: 5/10
# 15000/15000 [==========> 100%] - 6.66s | loss: 0.0612 | acc: 0.9841 | Val loss: 0.1234 | Val acc: 0.9656
# Epoch: 6/10
# 15000/15000 [==========> 100%] - 6.66s | loss: 0.0417 | acc: 0.9905 | Val loss: 0.1140 | Val acc: 0.9656
# Epoch: 7/10
# 15000/15000 [==========> 100%] - 6.68s | loss: 0.0289 | acc: 0.9943 | Val loss: 0.1128 | Val acc: 0.9656
# Epoch: 8/10
# 15000/15000 [==========> 100%] - 6.65s | loss: 0.0224 | acc: 0.9963 | Val loss: 0.1144 | Val acc: 0.9656
# Epoch: 9/10
# 15000/15000 [==========> 100%] - 6.68s | loss: 0.0148 | acc: 0.9973 | Val loss: 0.1076 | Val acc: 0.9680
# Epoch: 10/10
# 15000/15000 [==========> 100%] - 6.66s | loss: 0.0095 | acc: 0.9991 | Val loss: 0.1036 | Val acc: 0.9664
#
# *************************** Total Training Time = 0hr 1mins 6secs 716.29ms ***************************
#
# Sample: 3/20 -- Learning Rate: 0.001897 | Minibatch Size: 1199
# ==========================================================================================================
#
# Epoch: 1/10
# 15000/15000 [==========> 100%] - 6.58s | loss: 0.3186 | acc: 0.9102 | Val loss: 0.3120 | Val acc: 0.9184
# Epoch: 2/10
# 15000/15000 [==========> 100%] - 6.79s | loss: 0.1967 | acc: 0.9425 | Val loss: 0.2132 | Val acc: 0.9416
# Epoch: 3/10
# 15000/15000 [==========> 100%] - 6.76s | loss: 0.1446 | acc: 0.9598 | Val loss: 0.1784 | Val acc: 0.9496
# Epoch: 4/10
# 15000/15000 [==========> 100%] - 6.62s | loss: 0.0964 | acc: 0.9731 | Val loss: 0.1426 | Val acc: 0.9600
# Epoch: 5/10
# 15000/15000 [==========> 100%] - 6.64s | loss: 0.0710 | acc: 0.9809 | Val loss: 0.1338 | Val acc: 0.9640
# Epoch: 6/10
# 15000/15000 [==========> 100%] - 6.64s | loss: 0.0510 | acc: 0.9887 | Val loss: 0.1218 | Val acc: 0.9648
# Epoch: 7/10
# 15000/15000 [==========> 100%] - 6.65s | loss: 0.0357 | acc: 0.9931 | Val loss: 0.1191 | Val acc: 0.9664
# Epoch: 8/10
# 15000/15000 [==========> 100%] - 6.66s | loss: 0.0276 | acc: 0.9949 | Val loss: 0.1181 | Val acc: 0.9648
# Epoch: 9/10
# 15000/15000 [==========> 100%] - 6.66s | loss: 0.0183 | acc: 0.9971 | Val loss: 0.1064 | Val acc: 0.9704
# Epoch: 10/10
# 15000/15000 [==========> 100%] - 6.67s | loss: 0.0129 | acc: 0.9987 | Val loss: 0.1078 | Val acc: 0.9696
#
# *************************** Total Training Time = 0hr 1mins 6secs 945.30ms ***************************
#
# Sample: 4/20 -- Learning Rate: 0.001950 | Minibatch Size: 1201
# ==========================================================================================================
#
# Epoch: 1/10
# 15000/15000 [==========> 100%] - 6.65s | loss: 0.3181 | acc: 0.9102 | Val loss: 0.3136 | Val acc: 0.9152
# Epoch: 2/10
# 15000/15000 [==========> 100%] - 6.52s | loss: 0.1970 | acc: 0.9415 | Val loss: 0.2157 | Val acc: 0.9384
# Epoch: 3/10
# 15000/15000 [==========> 100%] - 6.58s | loss: 0.1416 | acc: 0.9601 | Val loss: 0.1769 | Val acc: 0.9496
# Epoch: 4/10
# 15000/15000 [==========> 100%] - 6.61s | loss: 0.0966 | acc: 0.9723 | Val loss: 0.1444 | Val acc: 0.9600
# Epoch: 5/10
# 15000/15000 [==========> 100%] - 6.65s | loss: 0.0690 | acc: 0.9817 | Val loss: 0.1319 | Val acc: 0.9632
# Epoch: 6/10
# 15000/15000 [==========> 100%] - 6.63s | loss: 0.0501 | acc: 0.9885 | Val loss: 0.1208 | Val acc: 0.9648
# Epoch: 7/10
# 15000/15000 [==========> 100%] - 6.66s | loss: 0.0351 | acc: 0.9929 | Val loss: 0.1188 | Val acc: 0.9640
# Epoch: 8/10
# 15000/15000 [==========> 100%] - 6.63s | loss: 0.0269 | acc: 0.9953 | Val loss: 0.1170 | Val acc: 0.9640
# Epoch: 9/10
# 15000/15000 [==========> 100%] - 6.65s | loss: 0.0189 | acc: 0.9973 | Val loss: 0.1079 | Val acc: 0.9704
# Epoch: 10/10
# 15000/15000 [==========> 100%] - 6.70s | loss: 0.0124 | acc: 0.9986 | Val loss: 0.1054 | Val acc: 0.9688
#
# *************************** Total Training Time = 0hr 1mins 6secs 580.64ms ***************************
#
# Sample: 5/20 -- Learning Rate: 0.002201 | Minibatch Size: 1266
# ==========================================================================================================
#
# Epoch: 1/10
# 15000/15000 [==========> 100%] - 6.18s | loss: 0.3434 | acc: 0.9006 | Val loss: 0.3329 | Val acc: 0.9072
# Epoch: 2/10
# 15000/15000 [==========> 100%] - 6.12s | loss: 0.2038 | acc: 0.9409 | Val loss: 0.2212 | Val acc: 0.9408
# Epoch: 3/10
# 15000/15000 [==========> 100%] - 6.17s | loss: 0.1424 | acc: 0.9593 | Val loss: 0.1714 | Val acc: 0.9560
# Epoch: 4/10
# 15000/15000 [==========> 100%] - 6.18s | loss: 0.1000 | acc: 0.9717 | Val loss: 0.1476 | Val acc: 0.9600
# Epoch: 5/10
# 15000/15000 [==========> 100%] - 6.22s | loss: 0.0695 | acc: 0.9813 | Val loss: 0.1291 | Val acc: 0.9664
# Epoch: 6/10
# 15000/15000 [==========> 100%] - 6.22s | loss: 0.0498 | acc: 0.9879 | Val loss: 0.1155 | Val acc: 0.9656
# Epoch: 7/10
# 15000/15000 [==========> 100%] - 6.24s | loss: 0.0370 | acc: 0.9917 | Val loss: 0.1223 | Val acc: 0.9632
# Epoch: 8/10
# 15000/15000 [==========> 100%] - 6.22s | loss: 0.0263 | acc: 0.9943 | Val loss: 0.1151 | Val acc: 0.9656
# Epoch: 9/10
# 15000/15000 [==========> 100%] - 6.28s | loss: 0.0198 | acc: 0.9963 | Val loss: 0.1095 | Val acc: 0.9664
# Epoch: 10/10
# 15000/15000 [==========> 100%] - 6.24s | loss: 0.0131 | acc: 0.9987 | Val loss: 0.1059 | Val acc: 0.9712
#
# *************************** Total Training Time = 0hr 1mins 2secs 367.25ms ***************************
#
# Sample: 6/20 -- Learning Rate: 0.001978 | Minibatch Size: 1197
# ==========================================================================================================
#
# Epoch: 1/10
# 15000/15000 [==========> 100%] - 6.59s | loss: 0.3130 | acc: 0.9115 | Val loss: 0.3049 | Val acc: 0.9216
# Epoch: 2/10
# 15000/15000 [==========> 100%] - 6.53s | loss: 0.1912 | acc: 0.9443 | Val loss: 0.2063 | Val acc: 0.9424
# Epoch: 3/10
# 15000/15000 [==========> 100%] - 6.61s | loss: 0.1393 | acc: 0.9617 | Val loss: 0.1743 | Val acc: 0.9504
# Epoch: 4/10
# 15000/15000 [==========> 100%] - 6.60s | loss: 0.0931 | acc: 0.9743 | Val loss: 0.1408 | Val acc: 0.9624
# Epoch: 5/10
# 15000/15000 [==========> 100%] - 6.65s | loss: 0.0683 | acc: 0.9811 | Val loss: 0.1321 | Val acc: 0.9640
# Epoch: 6/10
# 15000/15000 [==========> 100%] - 6.64s | loss: 0.0487 | acc: 0.9891 | Val loss: 0.1191 | Val acc: 0.9648
# Epoch: 7/10
# 15000/15000 [==========> 100%] - 6.62s | loss: 0.0333 | acc: 0.9933 | Val loss: 0.1167 | Val acc: 0.9664
# Epoch: 8/10
# 15000/15000 [==========> 100%] - 6.59s | loss: 0.0263 | acc: 0.9953 | Val loss: 0.1182 | Val acc: 0.9616
# Epoch: 9/10
# 15000/15000 [==========> 100%] - 6.61s | loss: 0.0164 | acc: 0.9980 | Val loss: 0.1034 | Val acc: 0.9720
# Epoch: 10/10
# 15000/15000 [==========> 100%] - 6.60s | loss: 0.0119 | acc: 0.9989 | Val loss: 0.1077 | Val acc: 0.9704
#
# *************************** Total Training Time = 0hr 1mins 6secs 338.78ms ***************************
#
# Sample: 7/20 -- Learning Rate: 0.002153 | Minibatch Size: 1240
# ==========================================================================================================
#
# Epoch: 1/10
# 15000/15000 [==========> 100%] - 6.50s | loss: 0.3237 | acc: 0.9081 | Val loss: 0.3186 | Val acc: 0.9128
# Epoch: 2/10
# 15000/15000 [==========> 100%] - 6.49s | loss: 0.2141 | acc: 0.9367 | Val loss: 0.2217 | Val acc: 0.9384
# Epoch: 3/10
# 15000/15000 [==========> 100%] - 6.73s | loss: 0.1381 | acc: 0.9605 | Val loss: 0.1698 | Val acc: 0.9568
# Epoch: 4/10
# 15000/15000 [==========> 100%] - 7.28s | loss: 0.1054 | acc: 0.9688 | Val loss: 0.1535 | Val acc: 0.9584
# Epoch: 5/10
# 15000/15000 [==========> 100%] - 6.76s | loss: 0.0814 | acc: 0.9765 | Val loss: 0.1396 | Val acc: 0.9624
# Epoch: 6/10
# 15000/15000 [==========> 100%] - 6.67s | loss: 0.0550 | acc: 0.9866 | Val loss: 0.1290 | Val acc: 0.9640
# Epoch: 7/10
# 15000/15000 [==========> 100%] - 6.73s | loss: 0.0400 | acc: 0.9910 | Val loss: 0.1203 | Val acc: 0.9616
# Epoch: 8/10
# 15000/15000 [==========> 100%] - 6.82s | loss: 0.0329 | acc: 0.9923 | Val loss: 0.1203 | Val acc: 0.9664
# Epoch: 9/10
# 15000/15000 [==========> 100%] - 6.66s | loss: 0.0222 | acc: 0.9957 | Val loss: 0.1079 | Val acc: 0.9672
# Epoch: 10/10
# 15000/15000 [==========> 100%] - 6.67s | loss: 0.0175 | acc: 0.9971 | Val loss: 0.1100 | Val acc: 0.9688
#
# *************************** Total Training Time = 0hr 1mins 7secs 624.19ms ***************************
#
# Sample: 8/20 -- Learning Rate: 0.002107 | Minibatch Size: 1235
# ==========================================================================================================
#
# Epoch: 1/10
# 15000/15000 [==========> 100%] - 6.59s | loss: 0.3327 | acc: 0.9038 | Val loss: 0.3304 | Val acc: 0.9080
# Epoch: 2/10
# 15000/15000 [==========> 100%] - 6.55s | loss: 0.2124 | acc: 0.9380 | Val loss: 0.2228 | Val acc: 0.9392
# Epoch: 3/10
# 15000/15000 [==========> 100%] - 6.60s | loss: 0.1383 | acc: 0.9605 | Val loss: 0.1684 | Val acc: 0.9552
# Epoch: 4/10
# 15000/15000 [==========> 100%] - 6.74s | loss: 0.1047 | acc: 0.9694 | Val loss: 0.1556 | Val acc: 0.9584
# Epoch: 5/10
# 15000/15000 [==========> 100%] - 6.66s | loss: 0.0776 | acc: 0.9781 | Val loss: 0.1370 | Val acc: 0.9592
# Epoch: 6/10
# 15000/15000 [==========> 100%] - 6.63s | loss: 0.0562 | acc: 0.9844 | Val loss: 0.1274 | Val acc: 0.9632
# Epoch: 7/10
# 15000/15000 [==========> 100%] - 6.67s | loss: 0.0387 | acc: 0.9911 | Val loss: 0.1190 | Val acc: 0.9632
# Epoch: 8/10
# 15000/15000 [==========> 100%] - 6.65s | loss: 0.0325 | acc: 0.9923 | Val loss: 0.1172 | Val acc: 0.9656
# Epoch: 9/10
# 15000/15000 [==========> 100%] - 6.67s | loss: 0.0237 | acc: 0.9949 | Val loss: 0.1109 | Val acc: 0.9688
# Epoch: 10/10
# 15000/15000 [==========> 100%] - 6.68s | loss: 0.0151 | acc: 0.9983 | Val loss: 0.1049 | Val acc: 0.9696
#
# *************************** Total Training Time = 0hr 1mins 6secs 742.08ms ***************************
#
# Sample: 9/20 -- Learning Rate: 0.001954 | Minibatch Size: 1200
# ==========================================================================================================
#
# Epoch: 1/10
# 15000/15000 [==========> 100%] - 6.60s | loss: 0.3198 | acc: 0.9091 | Val loss: 0.3148 | Val acc: 0.9160
# Epoch: 2/10
# 15000/15000 [==========> 100%] - 6.53s | loss: 0.1991 | acc: 0.9413 | Val loss: 0.2175 | Val acc: 0.9384
# Epoch: 3/10
# 15000/15000 [==========> 100%] - 6.60s | loss: 0.1426 | acc: 0.9600 | Val loss: 0.1758 | Val acc: 0.9496
# Epoch: 4/10
# 15000/15000 [==========> 100%] - 6.61s | loss: 0.0969 | acc: 0.9722 | Val loss: 0.1429 | Val acc: 0.9616
# Epoch: 5/10
# 15000/15000 [==========> 100%] - 6.84s | loss: 0.0686 | acc: 0.9821 | Val loss: 0.1303 | Val acc: 0.9648
# Epoch: 6/10
# 15000/15000 [==========> 100%] - 6.67s | loss: 0.0498 | acc: 0.9887 | Val loss: 0.1203 | Val acc: 0.9640
# Epoch: 7/10
# 15000/15000 [==========> 100%] - 6.67s | loss: 0.0349 | acc: 0.9929 | Val loss: 0.1183 | Val acc: 0.9640
# Epoch: 8/10
# 15000/15000 [==========> 100%] - 6.68s | loss: 0.0263 | acc: 0.9956 | Val loss: 0.1155 | Val acc: 0.9648
# Epoch: 9/10
# 15000/15000 [==========> 100%] - 6.67s | loss: 0.0181 | acc: 0.9974 | Val loss: 0.1070 | Val acc: 0.9712
# Epoch: 10/10
# 15000/15000 [==========> 100%] - 6.68s | loss: 0.0124 | acc: 0.9987 | Val loss: 0.1055 | Val acc: 0.9696
#
# *************************** Total Training Time = 0hr 1mins 6secs 836.71ms ***************************
#
# Sample: 10/20 -- Learning Rate: 0.002281 | Minibatch Size: 1236
# ==========================================================================================================
#
# Epoch: 1/10
# 15000/15000 [==========> 100%] - 6.60s | loss: 0.3322 | acc: 0.9038 | Val loss: 0.3279 | Val acc: 0.9096
# Epoch: 2/10
# 15000/15000 [==========> 100%] - 6.76s | loss: 0.2027 | acc: 0.9411 | Val loss: 0.2111 | Val acc: 0.9408
# Epoch: 3/10
# 15000/15000 [==========> 100%] - 7.40s | loss: 0.1341 | acc: 0.9619 | Val loss: 0.1643 | Val acc: 0.9568
# Epoch: 4/10
# 15000/15000 [==========> 100%] - 6.64s | loss: 0.1014 | acc: 0.9707 | Val loss: 0.1512 | Val acc: 0.9552
# Epoch: 5/10
# 15000/15000 [==========> 100%] - 6.71s | loss: 0.0737 | acc: 0.9793 | Val loss: 0.1339 | Val acc: 0.9608
# Epoch: 6/10
# 15000/15000 [==========> 100%] - 6.64s | loss: 0.0515 | acc: 0.9863 | Val loss: 0.1226 | Val acc: 0.9640
# Epoch: 7/10
# 15000/15000 [==========> 100%] - 6.66s | loss: 0.0376 | acc: 0.9911 | Val loss: 0.1186 | Val acc: 0.9640
# Epoch: 8/10
# 15000/15000 [==========> 100%] - 6.65s | loss: 0.0316 | acc: 0.9925 | Val loss: 0.1153 | Val acc: 0.9680
# Epoch: 9/10
# 15000/15000 [==========> 100%] - 6.68s | loss: 0.0247 | acc: 0.9941 | Val loss: 0.1120 | Val acc: 0.9680
# Epoch: 10/10
# 15000/15000 [==========> 100%] - 6.68s | loss: 0.0167 | acc: 0.9974 | Val loss: 0.1060 | Val acc: 0.9696
#
# *************************** Total Training Time = 0hr 1mins 7secs 706.80ms ***************************
#
# Sample: 11/20 -- Learning Rate: 0.001944 | Minibatch Size: 1213
# ==========================================================================================================
#
# Epoch: 1/10
# 15000/15000 [==========> 100%] - 6.57s | loss: 0.3137 | acc: 0.9121 | Val loss: 0.3115 | Val acc: 0.9128
# Epoch: 2/10
# 15000/15000 [==========> 100%] - 6.54s | loss: 0.1987 | acc: 0.9419 | Val loss: 0.2193 | Val acc: 0.9408
# Epoch: 3/10
# 15000/15000 [==========> 100%] - 6.66s | loss: 0.1412 | acc: 0.9607 | Val loss: 0.1750 | Val acc: 0.9536
# Epoch: 4/10
# 15000/15000 [==========> 100%] - 6.60s | loss: 0.0959 | acc: 0.9733 | Val loss: 0.1430 | Val acc: 0.9608
# Epoch: 5/10
# 15000/15000 [==========> 100%] - 6.63s | loss: 0.0705 | acc: 0.9808 | Val loss: 0.1340 | Val acc: 0.9608
# Epoch: 6/10
# 15000/15000 [==========> 100%] - 6.65s | loss: 0.0517 | acc: 0.9877 | Val loss: 0.1196 | Val acc: 0.9616
# Epoch: 7/10
# 15000/15000 [==========> 100%] - 6.64s | loss: 0.0352 | acc: 0.9923 | Val loss: 0.1179 | Val acc: 0.9656
# Epoch: 8/10
# 15000/15000 [==========> 100%] - 6.64s | loss: 0.0279 | acc: 0.9951 | Val loss: 0.1177 | Val acc: 0.9632
# Epoch: 9/10
# 15000/15000 [==========> 100%] - 6.68s | loss: 0.0185 | acc: 0.9969 | Val loss: 0.1067 | Val acc: 0.9712
# Epoch: 10/10
# 15000/15000 [==========> 100%] - 6.65s | loss: 0.0127 | acc: 0.9986 | Val loss: 0.1054 | Val acc: 0.9688
#
# *************************** Total Training Time = 0hr 1mins 6secs 543.74ms ***************************
#
# Sample: 12/20 -- Learning Rate: 0.002166 | Minibatch Size: 1218
# ==========================================================================================================
#
# Epoch: 1/10
# 15000/15000 [==========> 100%] - 6.59s | loss: 0.3184 | acc: 0.9092 | Val loss: 0.3177 | Val acc: 0.9096
# Epoch: 2/10
# 15000/15000 [==========> 100%] - 6.52s | loss: 0.2036 | acc: 0.9384 | Val loss: 0.2261 | Val acc: 0.9376
# Epoch: 3/10
# 15000/15000 [==========> 100%] - 6.55s | loss: 0.1390 | acc: 0.9598 | Val loss: 0.1704 | Val acc: 0.9544
# Epoch: 4/10
# 15000/15000 [==========> 100%] - 6.57s | loss: 0.0934 | acc: 0.9734 | Val loss: 0.1437 | Val acc: 0.9624
# Epoch: 5/10
# 15000/15000 [==========> 100%] - 6.59s | loss: 0.0650 | acc: 0.9825 | Val loss: 0.1291 | Val acc: 0.9640
# Epoch: 6/10
# 15000/15000 [==========> 100%] - 6.60s | loss: 0.0468 | acc: 0.9889 | Val loss: 0.1162 | Val acc: 0.9632
# Epoch: 7/10
# 15000/15000 [==========> 100%] - 6.61s | loss: 0.0321 | acc: 0.9937 | Val loss: 0.1136 | Val acc: 0.9648
# Epoch: 8/10
# 15000/15000 [==========> 100%] - 6.61s | loss: 0.0242 | acc: 0.9959 | Val loss: 0.1140 | Val acc: 0.9672
# Epoch: 9/10
# 15000/15000 [==========> 100%] - 7.25s | loss: 0.0174 | acc: 0.9972 | Val loss: 0.1072 | Val acc: 0.9688
# Epoch: 10/10
# 15000/15000 [==========> 100%] - 6.90s | loss: 0.0115 | acc: 0.9987 | Val loss: 0.1037 | Val acc: 0.9696
#
# *************************** Total Training Time = 0hr 1mins 7secs 88.50ms ***************************
#
# Sample: 13/20 -- Learning Rate: 0.002420 | Minibatch Size: 1204
# ==========================================================================================================
#
# Epoch: 1/10
# 15000/15000 [==========> 100%] - 6.65s | loss: 0.3208 | acc: 0.9062 | Val loss: 0.3158 | Val acc: 0.9120
# Epoch: 2/10
# 15000/15000 [==========> 100%] - 6.53s | loss: 0.2015 | acc: 0.9393 | Val loss: 0.2209 | Val acc: 0.9376
# Epoch: 3/10
# 15000/15000 [==========> 100%] - 6.73s | loss: 0.1337 | acc: 0.9615 | Val loss: 0.1631 | Val acc: 0.9592
# Epoch: 4/10
# 15000/15000 [==========> 100%] - 6.60s | loss: 0.0928 | acc: 0.9724 | Val loss: 0.1454 | Val acc: 0.9600
# Epoch: 5/10
# 15000/15000 [==========> 100%] - 6.64s | loss: 0.0605 | acc: 0.9839 | Val loss: 0.1205 | Val acc: 0.9656
# Epoch: 6/10
# 15000/15000 [==========> 100%] - 6.63s | loss: 0.0405 | acc: 0.9910 | Val loss: 0.1135 | Val acc: 0.9672
# Epoch: 7/10
# 15000/15000 [==========> 100%] - 6.67s | loss: 0.0289 | acc: 0.9943 | Val loss: 0.1120 | Val acc: 0.9656
# Epoch: 8/10
# 15000/15000 [==========> 100%] - 6.66s | loss: 0.0219 | acc: 0.9961 | Val loss: 0.1113 | Val acc: 0.9648
# Epoch: 9/10
# 15000/15000 [==========> 100%] - 6.67s | loss: 0.0145 | acc: 0.9976 | Val loss: 0.1061 | Val acc: 0.9680
# Epoch: 10/10
# 15000/15000 [==========> 100%] - 6.73s | loss: 0.0090 | acc: 0.9992 | Val loss: 0.1007 | Val acc: 0.9712
#
# *************************** Total Training Time = 0hr 1mins 6secs 810.42ms ***************************
#
# Sample: 14/20 -- Learning Rate: 0.002080 | Minibatch Size: 1204
# ==========================================================================================================
#
# Epoch: 1/10
# 15000/15000 [==========> 100%] - 6.58s | loss: 0.3146 | acc: 0.9105 | Val loss: 0.3103 | Val acc: 0.9184
# Epoch: 2/10
# 15000/15000 [==========> 100%] - 6.55s | loss: 0.1962 | acc: 0.9413 | Val loss: 0.2153 | Val acc: 0.9424
# Epoch: 3/10
# 15000/15000 [==========> 100%] - 6.60s | loss: 0.1398 | acc: 0.9607 | Val loss: 0.1731 | Val acc: 0.9536
# Epoch: 4/10
# 15000/15000 [==========> 100%] - 6.60s | loss: 0.0943 | acc: 0.9734 | Val loss: 0.1421 | Val acc: 0.9608
# Epoch: 5/10
# 15000/15000 [==========> 100%] - 6.66s | loss: 0.0649 | acc: 0.9833 | Val loss: 0.1270 | Val acc: 0.9672
# Epoch: 6/10
# 15000/15000 [==========> 100%] - 7.15s | loss: 0.0461 | acc: 0.9899 | Val loss: 0.1163 | Val acc: 0.9648
# Epoch: 7/10
# 15000/15000 [==========> 100%] - 6.97s | loss: 0.0329 | acc: 0.9934 | Val loss: 0.1159 | Val acc: 0.9656
# Epoch: 8/10
# 15000/15000 [==========> 100%] - 6.65s | loss: 0.0247 | acc: 0.9959 | Val loss: 0.1159 | Val acc: 0.9664
# Epoch: 9/10
# 15000/15000 [==========> 100%] - 6.79s | loss: 0.0167 | acc: 0.9973 | Val loss: 0.1066 | Val acc: 0.9688
# Epoch: 10/10
# 15000/15000 [==========> 100%] - 6.67s | loss: 0.0110 | acc: 0.9989 | Val loss: 0.1041 | Val acc: 0.9704
#
# *************************** Total Training Time = 0hr 1mins 7secs 494.97ms ***************************
#
# Sample: 15/20 -- Learning Rate: 0.001920 | Minibatch Size: 1264
# ==========================================================================================================
#
# Epoch: 1/10
# 15000/15000 [==========> 100%] - 6.15s | loss: 0.3391 | acc: 0.9027 | Val loss: 0.3309 | Val acc: 0.9048
# Epoch: 2/10
# 15000/15000 [==========> 100%] - 6.10s | loss: 0.2144 | acc: 0.9364 | Val loss: 0.2383 | Val acc: 0.9368
# Epoch: 3/10
# 15000/15000 [==========> 100%] - 6.15s | loss: 0.1492 | acc: 0.9582 | Val loss: 0.1772 | Val acc: 0.9544
# Epoch: 4/10
# 15000/15000 [==========> 100%] - 6.19s | loss: 0.1048 | acc: 0.9701 | Val loss: 0.1529 | Val acc: 0.9576
# Epoch: 5/10
# 15000/15000 [==========> 100%] - 6.22s | loss: 0.0750 | acc: 0.9803 | Val loss: 0.1317 | Val acc: 0.9648
# Epoch: 6/10
# 15000/15000 [==========> 100%] - 6.21s | loss: 0.0551 | acc: 0.9869 | Val loss: 0.1204 | Val acc: 0.9648
# Epoch: 7/10
# 15000/15000 [==========> 100%] - 6.24s | loss: 0.0410 | acc: 0.9909 | Val loss: 0.1254 | Val acc: 0.9648
# Epoch: 8/10
# 15000/15000 [==========> 100%] - 6.21s | loss: 0.0288 | acc: 0.9941 | Val loss: 0.1146 | Val acc: 0.9672
# Epoch: 9/10
# 15000/15000 [==========> 100%] - 6.25s | loss: 0.0228 | acc: 0.9957 | Val loss: 0.1096 | Val acc: 0.9680
# Epoch: 10/10
# 15000/15000 [==========> 100%] - 6.22s | loss: 0.0149 | acc: 0.9985 | Val loss: 0.1040 | Val acc: 0.9720
#
# *************************** Total Training Time = 0hr 1mins 2secs 242.61ms ***************************
#
# Sample: 16/20 -- Learning Rate: 0.002286 | Minibatch Size: 1265
# ==========================================================================================================
#
# Epoch: 1/10
# 15000/15000 [==========> 100%] - 6.16s | loss: 0.3441 | acc: 0.9003 | Val loss: 0.3320 | Val acc: 0.9120
# Epoch: 2/10
# 15000/15000 [==========> 100%] - 6.13s | loss: 0.1999 | acc: 0.9430 | Val loss: 0.2151 | Val acc: 0.9416
# Epoch: 3/10
# 15000/15000 [==========> 100%] - 6.19s | loss: 0.1403 | acc: 0.9605 | Val loss: 0.1702 | Val acc: 0.9560
# Epoch: 4/10
# 15000/15000 [==========> 100%] - 6.20s | loss: 0.0988 | acc: 0.9723 | Val loss: 0.1468 | Val acc: 0.9600
# Epoch: 5/10
# 15000/15000 [==========> 100%] - 6.24s | loss: 0.0677 | acc: 0.9819 | Val loss: 0.1275 | Val acc: 0.9672
# Epoch: 6/10
# 15000/15000 [==========> 100%] - 6.24s | loss: 0.0489 | acc: 0.9883 | Val loss: 0.1142 | Val acc: 0.9696
# Epoch: 7/10
# 15000/15000 [==========> 100%] - 6.25s | loss: 0.0360 | acc: 0.9922 | Val loss: 0.1221 | Val acc: 0.9624
# Epoch: 8/10
# 15000/15000 [==========> 100%] - 6.47s | loss: 0.0258 | acc: 0.9949 | Val loss: 0.1138 | Val acc: 0.9664
# Epoch: 9/10
# 15000/15000 [==========> 100%] - 6.71s | loss: 0.0191 | acc: 0.9967 | Val loss: 0.1086 | Val acc: 0.9656
# Epoch: 10/10
# 15000/15000 [==========> 100%] - 6.43s | loss: 0.0133 | acc: 0.9985 | Val loss: 0.1069 | Val acc: 0.9720
#
# *************************** Total Training Time = 0hr 1mins 3secs 306.99ms ***************************
#
# Sample: 17/20 -- Learning Rate: 0.002289 | Minibatch Size: 1260
# ==========================================================================================================
#
# Epoch: 1/10
# 15000/15000 [==========> 100%] - 6.17s | loss: 0.3411 | acc: 0.9029 | Val loss: 0.3285 | Val acc: 0.9096
# Epoch: 2/10
# 15000/15000 [==========> 100%] - 6.14s | loss: 0.2010 | acc: 0.9426 | Val loss: 0.2187 | Val acc: 0.9416
# Epoch: 3/10
# 15000/15000 [==========> 100%] - 6.19s | loss: 0.1402 | acc: 0.9595 | Val loss: 0.1697 | Val acc: 0.9576
# Epoch: 4/10
# 15000/15000 [==========> 100%] - 6.18s | loss: 0.0974 | acc: 0.9723 | Val loss: 0.1460 | Val acc: 0.9584
# Epoch: 5/10
# 15000/15000 [==========> 100%] - 6.35s | loss: 0.0670 | acc: 0.9817 | Val loss: 0.1268 | Val acc: 0.9664
# Epoch: 6/10
# 15000/15000 [==========> 100%] - 6.22s | loss: 0.0488 | acc: 0.9886 | Val loss: 0.1137 | Val acc: 0.9672
# Epoch: 7/10
# 15000/15000 [==========> 100%] - 6.24s | loss: 0.0366 | acc: 0.9917 | Val loss: 0.1236 | Val acc: 0.9632
# Epoch: 8/10
# 15000/15000 [==========> 100%] - 6.23s | loss: 0.0268 | acc: 0.9945 | Val loss: 0.1155 | Val acc: 0.9672
# Epoch: 9/10
# 15000/15000 [==========> 100%] - 6.20s | loss: 0.0193 | acc: 0.9965 | Val loss: 0.1096 | Val acc: 0.9664
# Epoch: 10/10
# 15000/15000 [==========> 100%] - 6.20s | loss: 0.0132 | acc: 0.9986 | Val loss: 0.1065 | Val acc: 0.9704
#
# *************************** Total Training Time = 0hr 1mins 2secs 404.31ms ***************************
#
# Sample: 18/20 -- Learning Rate: 0.002145 | Minibatch Size: 1256
# ==========================================================================================================
#
# Epoch: 1/10
# 15000/15000 [==========> 100%] - 6.09s | loss: 0.3362 | acc: 0.9041 | Val loss: 0.3270 | Val acc: 0.9096
# Epoch: 2/10
# 15000/15000 [==========> 100%] - 6.06s | loss: 0.2065 | acc: 0.9382 | Val loss: 0.2284 | Val acc: 0.9376
# Epoch: 3/10
# 15000/15000 [==========> 100%] - 6.11s | loss: 0.1413 | acc: 0.9602 | Val loss: 0.1718 | Val acc: 0.9552
# Epoch: 4/10
# 15000/15000 [==========> 100%] - 6.46s | loss: 0.0985 | acc: 0.9723 | Val loss: 0.1472 | Val acc: 0.9600
# Epoch: 5/10
# 15000/15000 [==========> 100%] - 6.76s | loss: 0.0687 | acc: 0.9818 | Val loss: 0.1257 | Val acc: 0.9664
# Epoch: 6/10
# 15000/15000 [==========> 100%] - 6.44s | loss: 0.0511 | acc: 0.9878 | Val loss: 0.1152 | Val acc: 0.9664
# Epoch: 7/10
# 15000/15000 [==========> 100%] - 6.57s | loss: 0.0369 | acc: 0.9920 | Val loss: 0.1213 | Val acc: 0.9640
# Epoch: 8/10
# 15000/15000 [==========> 100%] - 6.20s | loss: 0.0258 | acc: 0.9948 | Val loss: 0.1130 | Val acc: 0.9640
# Epoch: 9/10
# 15000/15000 [==========> 100%] - 6.22s | loss: 0.0201 | acc: 0.9964 | Val loss: 0.1089 | Val acc: 0.9664
# Epoch: 10/10
# 15000/15000 [==========> 100%] - 6.21s | loss: 0.0130 | acc: 0.9986 | Val loss: 0.1011 | Val acc: 0.9712
#
# *************************** Total Training Time = 0hr 1mins 3secs 426.91ms ***************************
#
# Sample: 19/20 -- Learning Rate: 0.002106 | Minibatch Size: 1266
# ==========================================================================================================
#
# Epoch: 1/10
# 15000/15000 [==========> 100%] - 6.15s | loss: 0.3407 | acc: 0.9021 | Val loss: 0.3311 | Val acc: 0.9064
# Epoch: 2/10
# 15000/15000 [==========> 100%] - 6.12s | loss: 0.2087 | acc: 0.9373 | Val loss: 0.2301 | Val acc: 0.9400
# Epoch: 3/10
# 15000/15000 [==========> 100%] - 6.16s | loss: 0.1440 | acc: 0.9590 | Val loss: 0.1716 | Val acc: 0.9552
# Epoch: 4/10
# 15000/15000 [==========> 100%] - 6.16s | loss: 0.1020 | acc: 0.9717 | Val loss: 0.1501 | Val acc: 0.9576
# Epoch: 5/10
# 15000/15000 [==========> 100%] - 6.20s | loss: 0.0714 | acc: 0.9807 | Val loss: 0.1274 | Val acc: 0.9648
# Epoch: 6/10
# 15000/15000 [==========> 100%] - 6.19s | loss: 0.0510 | acc: 0.9878 | Val loss: 0.1159 | Val acc: 0.9656
# Epoch: 7/10
# 15000/15000 [==========> 100%] - 6.22s | loss: 0.0376 | acc: 0.9919 | Val loss: 0.1210 | Val acc: 0.9640
# Epoch: 8/10
# 15000/15000 [==========> 100%] - 6.20s | loss: 0.0265 | acc: 0.9947 | Val loss: 0.1140 | Val acc: 0.9680
# Epoch: 9/10
# 15000/15000 [==========> 100%] - 6.21s | loss: 0.0207 | acc: 0.9964 | Val loss: 0.1096 | Val acc: 0.9648
# Epoch: 10/10
# 15000/15000 [==========> 100%] - 6.20s | loss: 0.0134 | acc: 0.9987 | Val loss: 0.1042 | Val acc: 0.9712
#
# *************************** Total Training Time = 0hr 1mins 2secs 107.57ms ***************************
#
# Sample: 20/20 -- Learning Rate: 0.002547 | Minibatch Size: 1255
# ==========================================================================================================
#
# Epoch: 1/10
# 15000/15000 [==========> 100%] - 6.14s | loss: 0.3523 | acc: 0.8979 | Val loss: 0.3349 | Val acc: 0.9120
# Epoch: 2/10
# 15000/15000 [==========> 100%] - 6.13s | loss: 0.2058 | acc: 0.9395 | Val loss: 0.2137 | Val acc: 0.9440
# Epoch: 3/10
# 15000/15000 [==========> 100%] - 6.16s | loss: 0.1395 | acc: 0.9601 | Val loss: 0.1698 | Val acc: 0.9552
# Epoch: 4/10
# 15000/15000 [==========> 100%] - 6.16s | loss: 0.0945 | acc: 0.9739 | Val loss: 0.1414 | Val acc: 0.9624
# Epoch: 5/10
# 15000/15000 [==========> 100%] - 6.21s | loss: 0.0653 | acc: 0.9833 | Val loss: 0.1253 | Val acc: 0.9656
# Epoch: 6/10
# 15000/15000 [==========> 100%] - 6.27s | loss: 0.0464 | acc: 0.9886 | Val loss: 0.1134 | Val acc: 0.9672
# Epoch: 7/10
# 15000/15000 [==========> 100%] - 6.21s | loss: 0.0329 | acc: 0.9934 | Val loss: 0.1186 | Val acc: 0.9632
# Epoch: 8/10
# 15000/15000 [==========> 100%] - 6.23s | loss: 0.0239 | acc: 0.9950 | Val loss: 0.1135 | Val acc: 0.9640
# Epoch: 9/10
# 15000/15000 [==========> 100%] - 6.22s | loss: 0.0181 | acc: 0.9963 | Val loss: 0.1103 | Val acc: 0.9672
# Epoch: 10/10
# 15000/15000 [==========> 100%] - 6.20s | loss: 0.0113 | acc: 0.9989 | Val loss: 0.1034 | Val acc: 0.9704
#
# *************************** Total Training Time = 0hr 1mins 2secs 209.70ms ***************************
# ==========================================================================================================
#
#
# *************************** Total Search Time = 0hr 21mins 48secs 582.42ms ***************************
#
#
# Detail Search Summary for Hyper Parameters with high Accuracy:
#
# +================+===============+================+
# | Validation Acc | Learning Rate | Minibatch Size |
# +================+===============+================+
# | 0.97040	 | 0.00236	 | 1199		  |
# | 0.97120	 | 0.00220	 | 1266		  |
# | 0.97040	 | 0.00228	 | 1236		  |
# | 0.97040	 | 0.00242	 | 1204		  |
# | 0.97120	 | 0.00229	 | 1265		  |
# | 0.97120	 | 0.00229	 | 1260		  |
# | 0.97120	 | 0.00255	 | 1255		  |
# +================+===============+================+
# New Search Space for Learning Rate: [0.002001,0.002747]
# New Search Space for Minibatch Size: [1179,1286]
# Best Score: 0.971200
# Best Hyper Params:
#  Learning Rate: 0.002201
#  Minibatch Size: 1266

# %%
print(score)
print(np.where(score == np.max(score)))

# %%
fig, ax = plt.subplots(figsize=(8,8))
im = plt.imshow(score,cmap="RdYlGn") #RdYlGn, PiYG, Accent,Blues,viridis, YlGnBu
fig.colorbar(im,ax=ax,fraction=0.045)

m = len(lr)
n = len(mbz)
    
ax.set_title("Result of Grid Search",fontsize=24,pad = 20)
ax.set_xticks(range(0,m))
ax.set_yticks(range(0,n))
ax.set_xlabel("Learning Rate", fontsize = 20)
ax.set_ylabel("Minibatch Size", fontsize = 20)

ax.set_xticklabels(lr,fontsize=16,rotation=45)
ax.set_yticklabels(mbz,fontsize=16)

#setting horizontal axes labeling to top.
ax.xaxis.set_ticks_position('top')
ax.xaxis.set_label_position('top')


# Turn off all the ticks
ax.tick_params(top=False,left=False)


thres = [0.88, 0.96]

for i in range(n):
    for j in range(m):
        ax.text(j, i, "%.4f"%(score[i, j]),
                       ha="center", va="center", color="w" if score[i,j] > thres[1] or score[i,j] < thres[0]  else "black")


fig.tight_layout()
plt.show()

# %%
cm_train = confusion_matrix(train_y_sample,prediction_train)

cm_dev = confusion_matrix(dev_y_sample,prediction_dev)

cm_test = confusion_matrix(test_y_sample,prediction_test)

# %%
metrics, macro_metrics, acc = model_metrics(cm_train)

# %%
save_model(file_name = "hyperParameters", parameters = hyper_params)

# %%
loaded_hyper_params = load_model(file_name = "final_model_adam_dropout")

# %%
for key,value in loaded_hyper_params.items():
    print(key + ": " + str(value))
